# %% [markdown]
# # # Architectural Hyperparameter Tuning
# # Focus: hidden_dim, num_layers, activation, optimizer_type

# %%
#############################################
# Step 1: Data and Fixed Parameters
#############################################
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "True"
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import joblib
from scipy.stats import wasserstein_distance
import matplotlib.pyplot as plt
import seaborn as sns

def set_seed(seed=42):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Load data and artifacts
X_train_df = pd.read_csv(r"D:\DS Northeastern\DS 5500 - Capstone\FraudFusion\Data\processed\X_train.csv")
y_train_df = pd.read_csv(r"D:\DS Northeastern\DS 5500 - Capstone\FraudFusion\Data\processed\y_train.csv")
scaler = joblib.load(r"D:\DS Northeastern\DS 5500 - Capstone\FraudFusion\Data\processed\standard_scaler.pkl")
cat_vocab = joblib.load(r"D:\DS Northeastern\DS 5500 - Capstone\FraudFusion\Data\processed\cat_vocab.pkl")

# Fixed parameters from best configuration
FIXED_PARAMS = {
    'w1': 0.2, 'w2': 0.55, 'lambda_eng': 0.15,
    'lr': 0.001, 'batch_size': 40, 'T_train': 800
}

# Feature setup
numeric_features = ['amt', 'lat', 'long', 'city_pop', 'merch_lat', 'merch_long',
                    'age', 'trans_hour', 'trans_day', 'trans_month', 'trans_dayofweek']
cat_features = ['merchant', 'category', 'gender', 'street', 'city', 'state', 'zip', 'job']
eng_indices = [numeric_features.index(f) for f in ['trans_hour', 'trans_day', 'trans_month', 'trans_dayofweek']]

# Filter and prepare data
fraud_mask = (y_train_df.iloc[:, 0] == 1)
X_train_num = X_train_df[numeric_features].loc[fraud_mask].values
X_train_cat = X_train_df[cat_features].loc[fraud_mask].values
X_nonfraud_num = X_train_df[numeric_features].loc[~fraud_mask].values

# Engineered feature constraints
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
eng_min = torch.tensor(np.min(X_train_num[:, eng_indices], axis=0), 
                      dtype=torch.float32, device=device)
eng_max = torch.tensor(np.max(X_train_num[:, eng_indices], axis=0),
                     dtype=torch.float32, device=device)

#############################################
# Step 2: Dataset and Model Setup
#############################################
class FraudDataset(Dataset):
    def __init__(self, num_data, cat_data):
        self.num_data = torch.tensor(num_data, dtype=torch.float32)
        self.cat_data = torch.tensor(cat_data, dtype=torch.long)
    def __len__(self): return len(self.num_data)
    def __getitem__(self, idx): return self.num_data[idx], self.cat_data[idx]

beta = torch.linspace(1e-4, 0.02, FIXED_PARAMS['T_train']).to(device)
alpha = 1 - beta
alpha_hat = torch.cumprod(alpha, dim=0)
X_nonfraud_tensor = torch.tensor(X_nonfraud_num, dtype=torch.float32).to(device)

#############################################
# Step 3: Model Architecture
#############################################
class AdvancedNoisePredictor(nn.Module):
    def __init__(self, num_input_dim, cat_vocab_sizes, 
                 hidden_dim=256, num_layers=3, 
                 activation='LeakyReLU', cat_embed_dim=2):
        super().__init__()
        self.embeddings = nn.ModuleDict()
        for col, vocab_size in cat_vocab_sizes.items():
            self.embeddings[col] = nn.Embedding(vocab_size, cat_embed_dim)
        
        cat_total_dim = len(cat_vocab_sizes) * cat_embed_dim
        self.mlp = nn.Sequential(
            nn.Linear(num_input_dim + cat_total_dim + 1, hidden_dim),
            self._get_activation(activation),
            *[nn.Sequential(
                nn.Linear(hidden_dim, hidden_dim),
                self._get_activation(activation)
              ) for _ in range(num_layers-1)],
            nn.Linear(hidden_dim, num_input_dim)
        )

    def _get_activation(self, name):
        return {'LeakyReLU': nn.LeakyReLU(), 'GELU': nn.GELU()}[name]

    def forward(self, x_num, x_cat, t):
        embeds = [self.embeddings[col](x_cat[:,i]) for i,col in enumerate(self.embeddings)]
        x = torch.cat([x_num, *embeds, (t.float()/FIXED_PARAMS['T_train']).unsqueeze(1)], dim=1)
        return self.mlp(x)

#############################################
# Step 4: Training Infrastructure
#############################################
def forward_diffusion(x0, t):
    sqrt_alpha_hat_t = torch.sqrt(alpha_hat[t]).unsqueeze(1)
    sqrt_one_minus_alpha_hat_t = torch.sqrt(1 - alpha_hat[t]).unsqueeze(1)
    noise = torch.randn_like(x0)
    return sqrt_alpha_hat_t * x0 + sqrt_one_minus_alpha_hat_t * noise, noise

def train_model(config, train_loader, num_epochs=150):
    model = AdvancedNoisePredictor(
        num_input_dim=len(numeric_features),
        cat_vocab_sizes={col: cat_vocab[col] for col in cat_features},
        hidden_dim=config['hidden_dim'],
        num_layers=config['num_layers'],
        activation=config['activation']
    ).to(device)
    
    optimizer = optim.Adam(model.parameters(), lr=FIXED_PARAMS['lr'])
    
    mu_nf = X_nonfraud_tensor.mean(dim=0)
    sigma_nf = X_nonfraud_tensor.std(dim=0) + 1e-5
    loss_components = {'total': [], 'mse': [], 'prior': [], 'triplet': [], 'eng': []}

    for epoch in range(num_epochs):
        model.train()
        epoch_losses = [0]*5  # total, mse, prior, triplet, eng
        
        for x_num, x_cat in train_loader:
            x_num, x_cat = x_num.to(device), x_cat.to(device)
            t = torch.randint(0, FIXED_PARAMS['T_train'], (x_num.size(0),), device=device)
            
            x_t, noise = forward_diffusion(x_num, t)
            pred_noise = model(x_t, x_cat, t)
            
            # Calculate losses
            mse_loss = F.mse_loss(pred_noise, noise)
            z = (pred_noise - mu_nf)/sigma_nf
            prior_loss = (1 - 2*(1 - torch.distributions.Normal(0,1).cdf(torch.abs(z)))).mean()
            x0_est = (x_t - torch.sqrt(1-alpha_hat[t]).unsqueeze(1)*pred_noise)/torch.sqrt(alpha_hat[t]).unsqueeze(1)
            rand_idx = torch.randint(0, len(X_nonfraud_tensor), (x_num.size(0),))
            triplet_loss = F.relu(F.pairwise_distance(x0_est, x_num) - 
                                 F.pairwise_distance(x0_est, X_nonfraud_tensor[rand_idx]) + 1).mean()
            eng_loss = torch.mean(F.relu(eng_min - x0_est[:,eng_indices]) + 
                                F.relu(x0_est[:,eng_indices] - eng_max))
            
            total_loss = (mse_loss + FIXED_PARAMS['w1']*prior_loss + 
                        FIXED_PARAMS['w2']*triplet_loss + FIXED_PARAMS['lambda_eng']*eng_loss)
            
            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()
            
            losses = [total_loss.item(), mse_loss.item(), prior_loss.item(), 
                     triplet_loss.item(), eng_loss.item()]
            for i in range(5): epoch_losses[i] += losses[i]
        
        batches = len(train_loader)
        for i, key in enumerate(loss_components): 
            loss_components[key].append(epoch_losses[i]/batches)
            
        if (epoch+1) % 10 == 0:
            print(f"Epoch {epoch+1}/{num_epochs} | "
                  f"Total: {loss_components['total'][-1]:.4f} | "
                  f"MSE: {loss_components['mse'][-1]:.4f} | "
                  f"Prior: {loss_components['prior'][-1]:.4f} | "
                  f"Triplet: {loss_components['triplet'][-1]:.4f} | "
                  f"Eng: {loss_components['eng'][-1]:.4f}")
    
    return model, loss_components

#############################################
# Step 5: Evaluation
#############################################
def generate_categorical_samples(num_samples):
    synthetic_cat = {}
    for col in cat_features:
        value_counts = pd.Series(X_train_cat[:, cat_features.index(col)]).value_counts(normalize=True)
        synthetic_cat[col] = np.random.choice(value_counts.index, size=num_samples, p=value_counts.values)
    return torch.tensor(pd.DataFrame(synthetic_cat).values, dtype=torch.long)

def generate_samples(model, num_samples=1000):
    model.eval()
    with torch.no_grad():
        synthetic_cat = generate_categorical_samples(num_samples).to(device)
        x_num = torch.randn(num_samples, len(numeric_features)).to(device)
        
        for t in reversed(range(FIXED_PARAMS['T_train'])):
            t_tensor = torch.full((num_samples,), t, device=device)
            pred_noise = model(x_num, synthetic_cat, t_tensor)
            beta_t = beta[t].view(1,1)
            sqrt_alpha_t = torch.sqrt(1 - beta_t)
            x_num = (x_num - beta_t*pred_noise/(torch.sqrt(1 - alpha_hat[t])))/sqrt_alpha_t
            if t > 0: x_num += torch.sqrt(beta_t)*torch.randn_like(x_num)
        
        x_num[:, eng_indices] = torch.clamp(x_num[:, eng_indices], eng_min, eng_max)
        return x_num.cpu().numpy()

def evaluate_model(model):
    synthetic_num = scaler.inverse_transform(generate_samples(model))
    real_num = scaler.inverse_transform(X_train_num)
    return np.mean([wasserstein_distance(real_num[:,i], synthetic_num[:,i]) 
                  for i in range(len(numeric_features))])

#############################################
# Step 6: Multiple Trial Evaluation
#############################################
def evaluate_config_multiple_trials(config, num_trials=5):
    trial_results = []
    
    for trial in range(num_trials):
        set_seed(42 + trial)
        print(f"\n=== Trial {trial + 1}/{num_trials} ===")
        
        train_loader = DataLoader(FraudDataset(X_train_num, X_train_cat), 
                                batch_size=FIXED_PARAMS['batch_size'], shuffle=True)
        
        model, loss_components = train_model(config, train_loader)
        ws_dist = evaluate_model(model)
        
        trial_results.append({
            'trial': trial + 1,
            'wasserstein': ws_dist,
            'final_loss': loss_components['total'][-1],
            'min_loss': min(loss_components['total'])
        })
        
        print(f"Trial {trial + 1} Results:")
        print(f"  Final Loss: {loss_components['total'][-1]:.4f}")
        print(f"  Min Loss: {min(loss_components['total']):.4f}")
        print(f"  Wasserstein: {ws_dist:.4f}")
    
    # Calculate statistics
    wasserstein_scores = [r['wasserstein'] for r in trial_results]
    mean_wasserstein = np.mean(wasserstein_scores)
    std_wasserstein = np.std(wasserstein_scores)
    
    print("\nOverall Results:")
    print(f"Mean Wasserstein: {mean_wasserstein:.4f} ± {std_wasserstein:.4f}")
    
    # Plot trial results
    plt.figure(figsize=(10, 5))
    plt.bar(range(1, num_trials + 1), wasserstein_scores)
    plt.axhline(y=mean_wasserstein, color='r', linestyle='--', label=f'Mean: {mean_wasserstein:.4f}')
    plt.fill_between(range(1, num_trials + 1), 
                     mean_wasserstein - std_wasserstein,
                     mean_wasserstein + std_wasserstein,
                     alpha=0.2, color='r')
    plt.xlabel('Trial')
    plt.ylabel('Wasserstein Distance')
    plt.title('Wasserstein Distance Across Trials')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    return trial_results

# Test configuration
config = {
    'hidden_dim': 256,
    'num_layers': 3,
    'activation': 'LeakyReLU',
    'optimizer_type': 'Adam'
}

trial_results = evaluate_config_multiple_trials(config, num_trials=5)
# Out:
# === Trial 1/5 ===
# Epoch 10/150 | Total: 0.5989 | MSE: 0.3415 | Prior: 0.4106 | Triplet: 0.1809 | Eng: 0.5053
# Epoch 20/150 | Total: 0.5016 | MSE: 0.2974 | Prior: 0.4167 | Triplet: 0.1204 | Eng: 0.3641
# Epoch 30/150 | Total: 0.4586 | MSE: 0.2775 | Prior: 0.4145 | Triplet: 0.0971 | Eng: 0.2989
# Epoch 40/150 | Total: 0.4234 | MSE: 0.2527 | Prior: 0.4223 | Triplet: 0.0788 | Eng: 0.2858
# Epoch 50/150 | Total: 0.4048 | MSE: 0.2445 | Prior: 0.4253 | Triplet: 0.0682 | Eng: 0.2514
# Epoch 60/150 | Total: 0.3828 | MSE: 0.2290 | Prior: 0.4287 | Triplet: 0.0596 | Eng: 0.2353
# Epoch 70/150 | Total: 0.3548 | MSE: 0.2159 | Prior: 0.4304 | Triplet: 0.0447 | Eng: 0.1879
# Epoch 80/150 | Total: 0.3501 | MSE: 0.2101 | Prior: 0.4327 | Triplet: 0.0448 | Eng: 0.1927
# Epoch 90/150 | Total: 0.3442 | MSE: 0.2050 | Prior: 0.4376 | Triplet: 0.0448 | Eng: 0.1801
# Epoch 100/150 | Total: 0.3225 | MSE: 0.1896 | Prior: 0.4397 | Triplet: 0.0388 | Eng: 0.1581
# Epoch 110/150 | Total: 0.3119 | MSE: 0.1811 | Prior: 0.4375 | Triplet: 0.0376 | Eng: 0.1508
# Epoch 120/150 | Total: 0.3031 | MSE: 0.1734 | Prior: 0.4429 | Triplet: 0.0332 | Eng: 0.1527
# Epoch 130/150 | Total: 0.3008 | MSE: 0.1714 | Prior: 0.4448 | Triplet: 0.0336 | Eng: 0.1466
# Epoch 140/150 | Total: 0.2994 | MSE: 0.1699 | Prior: 0.4440 | Triplet: 0.0342 | Eng: 0.1456
# Epoch 150/150 | Total: 0.2875 | MSE: 0.1592 | Prior: 0.4477 | Triplet: 0.0338 | Eng: 0.1345
# Trial 1 Results:
#   Final Loss: 0.2875
#   Min Loss: 0.2861
#   Wasserstein: 0.6034
#
# === Trial 2/5 ===
# Epoch 10/150 | Total: 0.5706 | MSE: 0.3287 | Prior: 0.4130 | Triplet: 0.1530 | Eng: 0.5008
# Epoch 20/150 | Total: 0.4914 | MSE: 0.2982 | Prior: 0.4127 | Triplet: 0.1030 | Eng: 0.3600
# Epoch 20/150 | Total: 0.4923 | MSE: 0.2930 | Prior: 0.4157 | Triplet: 0.1235 | Eng: 0.3214
# Epoch 30/150 | Total: 0.4666 | MSE: 0.2770 | Prior: 0.4194 | Triplet: 0.1051 | Eng: 0.3194
# Epoch 40/150 | Total: 0.4242 | MSE: 0.2580 | Prior: 0.4220 | Triplet: 0.0811 | Eng: 0.2478
# Epoch 50/150 | Total: 0.4074 | MSE: 0.2398 | Prior: 0.4282 | Triplet: 0.0785 | Eng: 0.2589
# Epoch 60/150 | Total: 0.3952 | MSE: 0.2408 | Prior: 0.4270 | Triplet: 0.0647 | Eng: 0.2223
# Epoch 70/150 | Total: 0.3700 | MSE: 0.2254 | Prior: 0.4286 | Triplet: 0.0496 | Eng: 0.2107
# Epoch 80/150 | Total: 0.3604 | MSE: 0.2144 | Prior: 0.4328 | Triplet: 0.0502 | Eng: 0.2124
# Epoch 90/150 | Total: 0.3472 | MSE: 0.2114 | Prior: 0.4332 | Triplet: 0.0439 | Eng: 0.1666
# Epoch 100/150 | Total: 0.3377 | MSE: 0.2013 | Prior: 0.4358 | Triplet: 0.0426 | Eng: 0.1724
# Epoch 110/150 | Total: 0.3286 | MSE: 0.1964 | Prior: 0.4388 | Triplet: 0.0362 | Eng: 0.1639
# Epoch 120/150 | Total: 0.3142 | MSE: 0.1853 | Prior: 0.4406 | Triplet: 0.0369 | Eng: 0.1368
# Epoch 130/150 | Total: 0.2981 | MSE: 0.1694 | Prior: 0.4441 | Triplet: 0.0354 | Eng: 0.1365
# Epoch 140/150 | Total: 0.3023 | MSE: 0.1724 | Prior: 0.4447 | Triplet: 0.0357 | Eng: 0.1418
# Epoch 150/150 | Total: 0.2981 | MSE: 0.1700 | Prior: 0.4414 | Triplet: 0.0360 | Eng: 0.1340
# Trial 5 Results:
#   Final Loss: 0.2981
#   Min Loss: 0.2914
#   Wasserstein: 0.7967
#
# Overall Results:
# Mean Wasserstein: 0.6761 ± 0.0844

# %%
# Test configuration
config = {
    'hidden_dim': 256,
    'num_layers': 2,
    'activation': 'LeakyReLU',
    'optimizer_type': 'Adam'
}

trial_results = evaluate_config_multiple_trials(config, num_trials=5)
# Out:
# === Trial 1/5 ===
# Epoch 10/150 | Total: 0.5733 | MSE: 0.3386 | Prior: 0.4243 | Triplet: 0.1634 | Eng: 0.3998
# Epoch 20/150 | Total: 0.4750 | MSE: 0.2946 | Prior: 0.4224 | Triplet: 0.1027 | Eng: 0.2630
# Epoch 30/150 | Total: 0.4366 | MSE: 0.2725 | Prior: 0.4182 | Triplet: 0.0859 | Eng: 0.2207
# Epoch 40/150 | Total: 0.3904 | MSE: 0.2401 | Prior: 0.4257 | Triplet: 0.0682 | Eng: 0.1841
# Epoch 50/150 | Total: 0.3748 | MSE: 0.2314 | Prior: 0.4271 | Triplet: 0.0588 | Eng: 0.1714
# Epoch 60/150 | Total: 0.3560 | MSE: 0.2157 | Prior: 0.4320 | Triplet: 0.0512 | Eng: 0.1715
# Epoch 140/150 | Total: 0.2880 | MSE: 0.1675 | Prior: 0.4448 | Triplet: 0.0324 | Eng: 0.0916
# Epoch 150/150 | Total: 0.2854 | MSE: 0.1659 | Prior: 0.4419 | Triplet: 0.0290 | Eng: 0.1014
# Trial 5 Results:
#   Final Loss: 0.2854
#   Min Loss: 0.2753
#   Wasserstein: 0.8147
#
# Overall Results:
# Mean Wasserstein: 0.7400 ± 0.0699

# %%
# Test multiple configurations with multiple trials
configs_to_test = [
    # Best single-run config
    {
        'hidden_dim': 288,
        'num_layers': 2,
        'activation': 'GELU',
        'optimizer_type': 'Adam'
    },
    # Second best single-run config
    {
        'hidden_dim': 256,
        'num_layers': 3,
        'activation': 'LeakyReLU',
        'optimizer_type': 'Adam'
    }
]

for config in configs_to_test:
    print(f"\nTesting configuration: {config}")
    trial_results = evaluate_config_multiple_trials(config, num_trials= 10)
# Out:
# Testing configuration: {'hidden_dim': 288, 'num_layers': 2, 'activation': 'GELU', 'optimizer_type': 'Adam'}
#
# === Trial 1/10 ===
# Epoch 10/150 | Total: 0.5274 | MSE: 0.3221 | Prior: 0.4185 | Triplet: 0.1407 | Eng: 0.2943
# Epoch 20/150 | Total: 0.4543 | MSE: 0.2824 | Prior: 0.4237 | Triplet: 0.0982 | Eng: 0.2206
# Epoch 30/150 | Total: 0.4208 | MSE: 0.2648 | Prior: 0.4193 | Triplet: 0.0781 | Eng: 0.1950
# Epoch 40/150 | Total: 0.3749 | MSE: 0.2345 | Prior: 0.4251 | Triplet: 0.0581 | Eng: 0.1561
# Epoch 50/150 | Total: 0.3565 | MSE: 0.2251 | Prior: 0.4264 | Triplet: 0.0482 | Eng: 0.1308
# Epoch 60/150 | Total: 0.3414 | MSE: 0.2103 | Prior: 0.4310 | Triplet: 0.0458 | Eng: 0.1315
# Epoch 70/150 | Total: 0.3260 | MSE: 0.2018 | Prior: 0.4318 | Triplet: 0.0364 | Eng: 0.1187
# Epoch 80/150 | Total: 0.3178 | MSE: 0.1962 | Prior: 0.4328 | Triplet: 0.0343 | Eng: 0.1080
# Epoch 90/150 | Total: 0.3142 | MSE: 0.1927 | Prior: 0.4366 | Triplet: 0.0368 | Eng: 0.0929
# Epoch 100/150 | Total: 0.2977 | MSE: 0.1783 | Prior: 0.4347 | Triplet: 0.0315 | Eng: 0.1013
# Epoch 110/150 | Total: 0.2885 | MSE: 0.1713 | Prior: 0.4373 | Triplet: 0.0309 | Eng: 0.0850
# Epoch 120/150 | Total: 0.2829 | MSE: 0.1641 | Prior: 0.4411 | Triplet: 0.0282 | Eng: 0.1003
# Epoch 130/150 | Total: 0.2772 | MSE: 0.1606 | Prior: 0.4423 | Triplet: 0.0277 | Eng: 0.0862
# Epoch 140/150 | Total: 0.2742 | MSE: 0.1581 | Prior: 0.4452 | Triplet: 0.0272 | Eng: 0.0805
# Epoch 150/150 | Total: 0.2655 | MSE: 0.1502 | Prior: 0.4469 | Triplet: 0.0271 | Eng: 0.0737
# Trial 1 Results:
#   Final Loss: 0.2655
#   Min Loss: 0.2655
# Trial 4 Results:
#   Final Loss: 0.2702
#   Min Loss: 0.2665
#   Wasserstein: 0.6125
#
# === Trial 5/10 ===
# Epoch 10/150 | Total: 0.5357 | MSE: 0.3367 | Prior: 0.4214 | Triplet: 0.1384 | Eng: 0.2579
# Epoch 20/150 | Total: 0.4528 | MSE: 0.2835 | Prior: 0.4239 | Triplet: 0.0984 | Eng: 0.2022
# Epoch 30/150 | Total: 0.4183 | MSE: 0.2630 | Prior: 0.4201 | Triplet: 0.0798 | Eng: 0.1826
# Epoch 40/150 | Total: 0.3826 | MSE: 0.2430 | Prior: 0.4220 | Triplet: 0.0591 | Eng: 0.1509
# Epoch 50/150 | Total: 0.3645 | MSE: 0.2255 | Prior: 0.4282 | Triplet: 0.0588 | Eng: 0.1396
# Epoch 60/150 | Total: 0.3603 | MSE: 0.2293 | Prior: 0.4255 | Triplet: 0.0492 | Eng: 0.1256
# Epoch 70/150 | Total: 0.3406 | MSE: 0.2116 | Prior: 0.4289 | Triplet: 0.0433 | Eng: 0.1290
# Epoch 80/150 | Total: 0.3251 | MSE: 0.2003 | Prior: 0.4335 | Triplet: 0.0404 | Eng: 0.1056
# Epoch 90/150 | Total: 0.3200 | MSE: 0.1977 | Prior: 0.4325 | Triplet: 0.0348 | Eng: 0.1113
# Epoch 100/150 | Total: 0.3144 | MSE: 0.1910 | Prior: 0.4342 | Triplet: 0.0350 | Eng: 0.1158
# Epoch 110/150 | Total: 0.2991 | MSE: 0.1785 | Prior: 0.4396 | Triplet: 0.0296 | Eng: 0.1098
# Epoch 120/150 | Total: 0.2942 | MSE: 0.1729 | Prior: 0.4395 | Triplet: 0.0320 | Eng: 0.1052
# Epoch 130/150 | Total: 0.2801 | MSE: 0.1600 | Prior: 0.4435 | Triplet: 0.0311 | Eng: 0.0948
# Epoch 140/150 | Total: 0.2781 | MSE: 0.1598 | Prior: 0.4450 | Triplet: 0.0276 | Eng: 0.0941
# Epoch 150/150 | Total: 0.2785 | MSE: 0.1618 | Prior: 0.4393 | Triplet: 0.0279 | Eng: 0.0904
# Trial 5 Results:
#   Final Loss: 0.2785
#   Min Loss: 0.2708
#   Wasserstein: 0.8726
#
# === Trial 6/10 ===
# Epoch 10/150 | Total: 0.5336 | MSE: 0.3258 | Prior: 0.4192 | Triplet: 0.1474 | Eng: 0.2860
# Epoch 20/150 | Total: 0.4546 | MSE: 0.2838 | Prior: 0.4212 | Triplet: 0.1028 | Eng: 0.2003
# Epoch 30/150 | Total: 0.4213 | MSE: 0.2692 | Prior: 0.4172 | Triplet: 0.0783 | Eng: 0.1706
# Epoch 40/150 | Total: 0.3888 | MSE: 0.2435 | Prior: 0.4221 | Triplet: 0.0703 | Eng: 0.1478
# Epoch 50/150 | Total: 0.3696 | MSE: 0.2319 | Prior: 0.4248 | Triplet: 0.0562 | Eng: 0.1461
# Epoch 60/150 | Total: 0.3468 | MSE: 0.2173 | Prior: 0.4276 | Triplet: 0.0438 | Eng: 0.1327
# Epoch 140/150 | Total: 0.2798 | MSE: 0.1636 | Prior: 0.4403 | Triplet: 0.0263 | Eng: 0.0911
# Epoch 150/150 | Total: 0.2788 | MSE: 0.1588 | Prior: 0.4430 | Triplet: 0.0304 | Eng: 0.0979
# Trial 10 Results:
#   Final Loss: 0.2788
#   Min Loss: 0.2709
#   Wasserstein: 0.6765
#
# Overall Results:
# Mean Wasserstein: 0.7024 ± 0.0952
# Testing configuration: {'hidden_dim': 256, 'num_layers': 3, 'activation': 'LeakyReLU', 'optimizer_type': 'Adam'}
#
# === Trial 1/10 ===
# Epoch 10/150 | Total: 0.5989 | MSE: 0.3415 | Prior: 0.4106 | Triplet: 0.1809 | Eng: 0.5053
# Epoch 20/150 | Total: 0.5016 | MSE: 0.2974 | Prior: 0.4167 | Triplet: 0.1204 | Eng: 0.3641
# Epoch 30/150 | Total: 0.4586 | MSE: 0.2775 | Prior: 0.4145 | Triplet: 0.0971 | Eng: 0.2989
# Epoch 40/150 | Total: 0.4234 | MSE: 0.2527 | Prior: 0.4223 | Triplet: 0.0788 | Eng: 0.2858
# Epoch 50/150 | Total: 0.4048 | MSE: 0.2445 | Prior: 0.4253 | Triplet: 0.0682 | Eng: 0.2514
# Epoch 60/150 | Total: 0.3828 | MSE: 0.2290 | Prior: 0.4287 | Triplet: 0.0596 | Eng: 0.2353
# Epoch 70/150 | Total: 0.3548 | MSE: 0.2159 | Prior: 0.4304 | Triplet: 0.0447 | Eng: 0.1879
# Epoch 80/150 | Total: 0.3501 | MSE: 0.2101 | Prior: 0.4327 | Triplet: 0.0448 | Eng: 0.1927
# Epoch 90/150 | Total: 0.3442 | MSE: 0.2050 | Prior: 0.4376 | Triplet: 0.0448 | Eng: 0.1801
# Epoch 100/150 | Total: 0.3225 | MSE: 0.1896 | Prior: 0.4397 | Triplet: 0.0388 | Eng: 0.1581
# Epoch 110/150 | Total: 0.3119 | MSE: 0.1811 | Prior: 0.4375 | Triplet: 0.0376 | Eng: 0.1508
# Epoch 120/150 | Total: 0.3031 | MSE: 0.1734 | Prior: 0.4429 | Triplet: 0.0332 | Eng: 0.1527
# Epoch 130/150 | Total: 0.3008 | MSE: 0.1714 | Prior: 0.4448 | Triplet: 0.0336 | Eng: 0.1466
# Epoch 140/150 | Total: 0.2994 | MSE: 0.1699 | Prior: 0.4440 | Triplet: 0.0342 | Eng: 0.1456
# Epoch 150/150 | Total: 0.2875 | MSE: 0.1592 | Prior: 0.4477 | Triplet: 0.0338 | Eng: 0.1345
# Trial 1 Results:
#   Final Loss: 0.2875
#   Min Loss: 0.2861
#   Wasserstein: 0.6034
#
# === Trial 2/10 ===
# Epoch 10/150 | Total: 0.5706 | MSE: 0.3287 | Prior: 0.4130 | Triplet: 0.1530 | Eng: 0.5008
# Epoch 20/150 | Total: 0.4914 | MSE: 0.2982 | Prior: 0.4127 | Triplet: 0.1030 | Eng: 0.3600
# Epoch 30/150 | Total: 0.4570 | MSE: 0.2677 | Prior: 0.4245 | Triplet: 0.1014 | Eng: 0.3245
# Epoch 120/150 | Total: 0.3119 | MSE: 0.1780 | Prior: 0.4427 | Triplet: 0.0399 | Eng: 0.1556
# Epoch 130/150 | Total: 0.2972 | MSE: 0.1704 | Prior: 0.4456 | Triplet: 0.0313 | Eng: 0.1361
# Epoch 140/150 | Total: 0.3040 | MSE: 0.1766 | Prior: 0.4423 | Triplet: 0.0324 | Eng: 0.1411
# Epoch 150/150 | Total: 0.2933 | MSE: 0.1635 | Prior: 0.4454 | Triplet: 0.0361 | Eng: 0.1390
# Trial 3 Results:
#   Final Loss: 0.2933
#   Min Loss: 0.2888
#   Wasserstein: 0.7600
#
# === Trial 4/10 ===
# Epoch 10/150 | Total: 0.5874 | MSE: 0.3406 | Prior: 0.4101 | Triplet: 0.1718 | Eng: 0.4679
# Epoch 20/150 | Total: 0.4852 | MSE: 0.2872 | Prior: 0.4161 | Triplet: 0.1152 | Eng: 0.3427
# Epoch 30/150 | Total: 0.4452 | MSE: 0.2645 | Prior: 0.4228 | Triplet: 0.0882 | Eng: 0.3174
# Epoch 40/150 | Total: 0.4174 | MSE: 0.2542 | Prior: 0.4255 | Triplet: 0.0716 | Eng: 0.2582
# Epoch 50/150 | Total: 0.3899 | MSE: 0.2339 | Prior: 0.4289 | Triplet: 0.0610 | Eng: 0.2442
# Epoch 60/150 | Total: 0.3764 | MSE: 0.2267 | Prior: 0.4287 | Triplet: 0.0551 | Eng: 0.2240
# Epoch 70/150 | Total: 0.3708 | MSE: 0.2220 | Prior: 0.4313 | Triplet: 0.0530 | Eng: 0.2227
# Epoch 80/150 | Total: 0.3492 | MSE: 0.2101 | Prior: 0.4308 | Triplet: 0.0474 | Eng: 0.1792
# Epoch 90/150 | Total: 0.3410 | MSE: 0.2016 | Prior: 0.4378 | Triplet: 0.0436 | Eng: 0.1855
# Epoch 100/150 | Total: 0.3262 | MSE: 0.1920 | Prior: 0.4383 | Triplet: 0.0401 | Eng: 0.1637
# Epoch 110/150 | Total: 0.3168 | MSE: 0.1827 | Prior: 0.4437 | Triplet: 0.0379 | Eng: 0.1630
# Epoch 120/150 | Total: 0.3193 | MSE: 0.1857 | Prior: 0.4399 | Triplet: 0.0379 | Eng: 0.1650
# Epoch 130/150 | Total: 0.2981 | MSE: 0.1714 | Prior: 0.4425 | Triplet: 0.0327 | Eng: 0.1346
# Epoch 140/150 | Total: 0.2985 | MSE: 0.1700 | Prior: 0.4430 | Triplet: 0.0340 | Eng: 0.1413
# Epoch 150/150 | Total: 0.2838 | MSE: 0.1596 | Prior: 0.4448 | Triplet: 0.0282 | Eng: 0.1318
# Trial 4 Results:
#   Final Loss: 0.2838
#   Min Loss: 0.2838
#   Wasserstein: 0.6095
#
# === Trial 5/10 ===
# Epoch 10/150 | Total: 0.5829 | MSE: 0.3438 | Prior: 0.4085 | Triplet: 0.1670 | Eng: 0.4373
# Epoch 20/150 | Total: 0.4923 | MSE: 0.2930 | Prior: 0.4157 | Triplet: 0.1235 | Eng: 0.3214
# Epoch 30/150 | Total: 0.4666 | MSE: 0.2770 | Prior: 0.4194 | Triplet: 0.1051 | Eng: 0.3194
# Epoch 40/150 | Total: 0.4242 | MSE: 0.2580 | Prior: 0.4220 | Triplet: 0.0811 | Eng: 0.2478
# Epoch 50/150 | Total: 0.4074 | MSE: 0.2398 | Prior: 0.4282 | Triplet: 0.0785 | Eng: 0.2589
# Epoch 60/150 | Total: 0.3952 | MSE: 0.2408 | Prior: 0.4270 | Triplet: 0.0647 | Eng: 0.2223
# Epoch 70/150 | Total: 0.3700 | MSE: 0.2254 | Prior: 0.4286 | Triplet: 0.0496 | Eng: 0.2107
# Epoch 80/150 | Total: 0.3604 | MSE: 0.2144 | Prior: 0.4328 | Triplet: 0.0502 | Eng: 0.2124
# Epoch 90/150 | Total: 0.3472 | MSE: 0.2114 | Prior: 0.4332 | Triplet: 0.0439 | Eng: 0.1666
# Epoch 100/150 | Total: 0.3377 | MSE: 0.2013 | Prior: 0.4358 | Triplet: 0.0426 | Eng: 0.1724
# Epoch 110/150 | Total: 0.3286 | MSE: 0.1964 | Prior: 0.4388 | Triplet: 0.0362 | Eng: 0.1639
# Epoch 120/150 | Total: 0.3142 | MSE: 0.1853 | Prior: 0.4406 | Triplet: 0.0369 | Eng: 0.1368
# Epoch 130/150 | Total: 0.2981 | MSE: 0.1694 | Prior: 0.4441 | Triplet: 0.0354 | Eng: 0.1365
# Epoch 140/150 | Total: 0.3023 | MSE: 0.1724 | Prior: 0.4447 | Triplet: 0.0357 | Eng: 0.1418
# Epoch 150/150 | Total: 0.2981 | MSE: 0.1700 | Prior: 0.4414 | Triplet: 0.0360 | Eng: 0.1340
# Trial 5 Results:
#   Final Loss: 0.2981
#   Min Loss: 0.2914
#   Wasserstein: 0.7967
#
# === Trial 6/10 ===
# Epoch 10/150 | Total: 0.5897 | MSE: 0.3438 | Prior: 0.4187 | Triplet: 0.1647 | Eng: 0.4770
# Epoch 20/150 | Total: 0.4976 | MSE: 0.2964 | Prior: 0.4149 | Triplet: 0.1229 | Eng: 0.3372
# Epoch 30/150 | Total: 0.4579 | MSE: 0.2769 | Prior: 0.4153 | Triplet: 0.0972 | Eng: 0.2961
# Epoch 40/150 | Total: 0.4276 | MSE: 0.2524 | Prior: 0.4246 | Triplet: 0.0888 | Eng: 0.2764
# Epoch 50/150 | Total: 0.4034 | MSE: 0.2438 | Prior: 0.4235 | Triplet: 0.0714 | Eng: 0.2380
# Epoch 60/150 | Total: 0.3815 | MSE: 0.2266 | Prior: 0.4309 | Triplet: 0.0618 | Eng: 0.2313
# Epoch 70/150 | Total: 0.3701 | MSE: 0.2159 | Prior: 0.4300 | Triplet: 0.0558 | Eng: 0.2496
# Epoch 80/150 | Total: 0.3560 | MSE: 0.2173 | Prior: 0.4307 | Triplet: 0.0437 | Eng: 0.1904
# Epoch 90/150 | Total: 0.3428 | MSE: 0.2055 | Prior: 0.4357 | Triplet: 0.0424 | Eng: 0.1788
# Epoch 100/150 | Total: 0.3318 | MSE: 0.1946 | Prior: 0.4401 | Triplet: 0.0424 | Eng: 0.1725
# Epoch 110/150 | Total: 0.3197 | MSE: 0.1874 | Prior: 0.4387 | Triplet: 0.0362 | Eng: 0.1642
# Epoch 120/150 | Total: 0.3126 | MSE: 0.1802 | Prior: 0.4414 | Triplet: 0.0355 | Eng: 0.1641
# Epoch 130/150 | Total: 0.3070 | MSE: 0.1775 | Prior: 0.4441 | Triplet: 0.0353 | Eng: 0.1416
# Epoch 140/150 | Total: 0.2969 | MSE: 0.1692 | Prior: 0.4431 | Triplet: 0.0337 | Eng: 0.1367
# Epoch 150/150 | Total: 0.2914 | MSE: 0.1650 | Prior: 0.4442 | Triplet: 0.0313 | Eng: 0.1350
# Trial 6 Results:
#   Final Loss: 0.2914
#   Min Loss: 0.2913
#   Wasserstein: 0.8175
#
# === Trial 7/10 ===
# Epoch 10/150 | Total: 0.5758 | MSE: 0.3401 | Prior: 0.4124 | Triplet: 0.1552 | Eng: 0.4519
# Epoch 20/150 | Total: 0.5094 | MSE: 0.3010 | Prior: 0.4153 | Triplet: 0.1245 | Eng: 0.3792
# Epoch 30/150 | Total: 0.4364 | MSE: 0.2623 | Prior: 0.4196 | Triplet: 0.0912 | Eng: 0.2666
# Epoch 40/150 | Total: 0.4220 | MSE: 0.2511 | Prior: 0.4205 | Triplet: 0.0812 | Eng: 0.2811
# Epoch 50/150 | Total: 0.4042 | MSE: 0.2441 | Prior: 0.4259 | Triplet: 0.0717 | Eng: 0.2367
# Epoch 60/150 | Total: 0.3817 | MSE: 0.2265 | Prior: 0.4334 | Triplet: 0.0619 | Eng: 0.2298
# Epoch 70/150 | Total: 0.3660 | MSE: 0.2157 | Prior: 0.4330 | Triplet: 0.0546 | Eng: 0.2247
# Epoch 80/150 | Total: 0.3568 | MSE: 0.2141 | Prior: 0.4350 | Triplet: 0.0466 | Eng: 0.2003
# Epoch 90/150 | Total: 0.3432 | MSE: 0.2022 | Prior: 0.4371 | Triplet: 0.0437 | Eng: 0.1975
# Epoch 100/150 | Total: 0.3244 | MSE: 0.1911 | Prior: 0.4376 | Triplet: 0.0403 | Eng: 0.1570
# Epoch 110/150 | Total: 0.3206 | MSE: 0.1840 | Prior: 0.4415 | Triplet: 0.0412 | Eng: 0.1705
# Epoch 120/150 | Total: 0.3103 | MSE: 0.1785 | Prior: 0.4424 | Triplet: 0.0355 | Eng: 0.1586
# Epoch 130/150 | Total: 0.3035 | MSE: 0.1727 | Prior: 0.4448 | Triplet: 0.0373 | Eng: 0.1419
# Epoch 140/150 | Total: 0.3019 | MSE: 0.1723 | Prior: 0.4453 | Triplet: 0.0383 | Eng: 0.1295
# Epoch 150/150 | Total: 0.2947 | MSE: 0.1660 | Prior: 0.4459 | Triplet: 0.0341 | Eng: 0.1386
# Trial 7 Results:
#   Final Loss: 0.2947
#   Min Loss: 0.2896
#   Wasserstein: 0.9197
#
# === Trial 8/10 ===
# Epoch 10/150 | Total: 0.5779 | MSE: 0.3394 | Prior: 0.4100 | Triplet: 0.1683 | Eng: 0.4262
# Epoch 20/150 | Total: 0.4892 | MSE: 0.2916 | Prior: 0.4138 | Triplet: 0.1156 | Eng: 0.3415
# Epoch 30/150 | Total: 0.4495 | MSE: 0.2659 | Prior: 0.4219 | Triplet: 0.0979 | Eng: 0.3027
# Epoch 40/150 | Total: 0.4143 | MSE: 0.2445 | Prior: 0.4228 | Triplet: 0.0752 | Eng: 0.2924
# Epoch 50/150 | Total: 0.3967 | MSE: 0.2402 | Prior: 0.4243 | Triplet: 0.0646 | Eng: 0.2408
# Epoch 60/150 | Total: 0.3758 | MSE: 0.2280 | Prior: 0.4250 | Triplet: 0.0540 | Eng: 0.2207
# Epoch 70/150 | Total: 0.3598 | MSE: 0.2170 | Prior: 0.4302 | Triplet: 0.0503 | Eng: 0.1942
# Epoch 80/150 | Total: 0.3548 | MSE: 0.2144 | Prior: 0.4342 | Triplet: 0.0478 | Eng: 0.1820
# Epoch 90/150 | Total: 0.3426 | MSE: 0.2048 | Prior: 0.4373 | Triplet: 0.0422 | Eng: 0.1811
# Epoch 100/150 | Total: 0.3228 | MSE: 0.1902 | Prior: 0.4403 | Triplet: 0.0365 | Eng: 0.1629
# Epoch 110/150 | Total: 0.3172 | MSE: 0.1825 | Prior: 0.4410 | Triplet: 0.0371 | Eng: 0.1735
# Epoch 120/150 | Total: 0.3115 | MSE: 0.1759 | Prior: 0.4468 | Triplet: 0.0368 | Eng: 0.1732
# Epoch 130/150 | Total: 0.3006 | MSE: 0.1712 | Prior: 0.4452 | Triplet: 0.0350 | Eng: 0.1406
# Epoch 140/150 | Total: 0.2940 | MSE: 0.1690 | Prior: 0.4462 | Triplet: 0.0313 | Eng: 0.1236
# Epoch 150/150 | Total: 0.2893 | MSE: 0.1635 | Prior: 0.4474 | Triplet: 0.0306 | Eng: 0.1299
# Trial 8 Results:
#   Final Loss: 0.2893
#   Min Loss: 0.2890
#   Wasserstein: 0.7728
#
# === Trial 9/10 ===
# Epoch 10/150 | Total: 0.5672 | MSE: 0.3348 | Prior: 0.4087 | Triplet: 0.1597 | Eng: 0.4187
# Epoch 20/150 | Total: 0.4931 | MSE: 0.2867 | Prior: 0.4174 | Triplet: 0.1300 | Eng: 0.3428
# Epoch 30/150 | Total: 0.4748 | MSE: 0.2868 | Prior: 0.4169 | Triplet: 0.1100 | Eng: 0.2947
# Epoch 40/150 | Total: 0.4343 | MSE: 0.2672 | Prior: 0.4209 | Triplet: 0.0863 | Eng: 0.2365
# Epoch 50/150 | Total: 0.4105 | MSE: 0.2475 | Prior: 0.4233 | Triplet: 0.0749 | Eng: 0.2477
# Epoch 60/150 | Total: 0.3909 | MSE: 0.2353 | Prior: 0.4282 | Triplet: 0.0644 | Eng: 0.2307
# Epoch 70/150 | Total: 0.3770 | MSE: 0.2222 | Prior: 0.4325 | Triplet: 0.0624 | Eng: 0.2272
# Epoch 80/150 | Total: 0.3659 | MSE: 0.2202 | Prior: 0.4342 | Triplet: 0.0503 | Eng: 0.2077
# Epoch 90/150 | Total: 0.3475 | MSE: 0.2051 | Prior: 0.4353 | Triplet: 0.0457 | Eng: 0.2016
# Epoch 100/150 | Total: 0.3363 | MSE: 0.1996 | Prior: 0.4339 | Triplet: 0.0465 | Eng: 0.1621
# Epoch 110/150 | Total: 0.3204 | MSE: 0.1881 | Prior: 0.4392 | Triplet: 0.0400 | Eng: 0.1496
# Epoch 120/150 | Total: 0.3147 | MSE: 0.1830 | Prior: 0.4420 | Triplet: 0.0361 | Eng: 0.1566
# Epoch 130/150 | Total: 0.3024 | MSE: 0.1734 | Prior: 0.4417 | Triplet: 0.0341 | Eng: 0.1458
# Epoch 140/150 | Total: 0.3000 | MSE: 0.1726 | Prior: 0.4415 | Triplet: 0.0340 | Eng: 0.1360
# Epoch 150/150 | Total: 0.3003 | MSE: 0.1670 | Prior: 0.4458 | Triplet: 0.0396 | Eng: 0.1493
# Trial 9 Results:
#   Final Loss: 0.3003
#   Min Loss: 0.2871
#   Wasserstein: 0.6602
#
# === Trial 10/10 ===
# Epoch 10/150 | Total: 0.5726 | MSE: 0.3329 | Prior: 0.4082 | Triplet: 0.1660 | Eng: 0.4451
# Epoch 20/150 | Total: 0.4966 | MSE: 0.2931 | Prior: 0.4173 | Triplet: 0.1286 | Eng: 0.3286
# Epoch 30/150 | Total: 0.4508 | MSE: 0.2685 | Prior: 0.4195 | Triplet: 0.1019 | Eng: 0.2824
# Epoch 40/150 | Total: 0.4226 | MSE: 0.2517 | Prior: 0.4234 | Triplet: 0.0790 | Eng: 0.2858
# Epoch 50/150 | Total: 0.4039 | MSE: 0.2404 | Prior: 0.4286 | Triplet: 0.0764 | Eng: 0.2388
# Epoch 60/150 | Total: 0.3954 | MSE: 0.2317 | Prior: 0.4287 | Triplet: 0.0643 | Eng: 0.2834
# Epoch 70/150 | Total: 0.3654 | MSE: 0.2154 | Prior: 0.4340 | Triplet: 0.0567 | Eng: 0.2131
# Epoch 80/150 | Total: 0.3626 | MSE: 0.2172 | Prior: 0.4327 | Triplet: 0.0541 | Eng: 0.1939
# Epoch 90/150 | Total: 0.3316 | MSE: 0.1932 | Prior: 0.4386 | Triplet: 0.0451 | Eng: 0.1728
# Epoch 100/150 | Total: 0.3312 | MSE: 0.1991 | Prior: 0.4385 | Triplet: 0.0391 | Eng: 0.1531
# Epoch 110/150 | Total: 0.3211 | MSE: 0.1904 | Prior: 0.4380 | Triplet: 0.0375 | Eng: 0.1494
# Epoch 120/150 | Total: 0.3071 | MSE: 0.1814 | Prior: 0.4418 | Triplet: 0.0350 | Eng: 0.1204
# Epoch 130/150 | Total: 0.3020 | MSE: 0.1739 | Prior: 0.4417 | Triplet: 0.0353 | Eng: 0.1360
# Epoch 140/150 | Total: 0.3025 | MSE: 0.1727 | Prior: 0.4425 | Triplet: 0.0346 | Eng: 0.1487
# Epoch 150/150 | Total: 0.2963 | MSE: 0.1677 | Prior: 0.4437 | Triplet: 0.0334 | Eng: 0.1434
# Trial 10 Results:
#   Final Loss: 0.2963
#   Min Loss: 0.2850
#   Wasserstein: 0.6468
#
# Overall Results:
# Mean Wasserstein: 0.7197 ± 0.1031
