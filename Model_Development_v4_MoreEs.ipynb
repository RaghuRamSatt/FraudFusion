# %%
#############################################
# FraudDiffuse Model for Sparkov Dataset
# Following the paper EXACTLY:
# 1. Data is preprocessed using Data_Preprocessing.ipynb,
#    so numeric features are log-transformed & standardized,
#    and categorical features are factorized.
# 2. Preprocessed artifacts (standard_scaler, cat_vocab, cat_mapping)
#    are saved in Data/processed – we load them here for consistency.
# 3. The diffusion model is trained on fraud samples only.
# 4. The model uses an adaptive non-fraud numeric prior for a probability loss,
#    and categorical features are handled via embedding layers.
#############################################

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "True"

import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

#############################################
# Step 1: Load Preprocessed Data & Artifacts
#############################################
X_train_df = pd.read_csv("Data/processed/X_train.csv")
y_train_df = pd.read_csv("Data/processed/y_train.csv")

# Load saved StandardScaler (for numeric features)
scaler = joblib.load("Data/processed/standard_scaler.pkl")
# Load the categorical vocabulary dictionary and mapping
cat_vocab = joblib.load("Data/processed/cat_vocab.pkl")
cat_mapping = joblib.load("Data/processed/cat_mapping.pkl")
print("Loaded transformation artifacts from Data/processed.")

# Define feature lists exactly as in your preprocessing:
# (Adjust these lists to match your Data_Preprocessing.ipynb)
num_features = ['amt', 'lat', 'long', 'city_pop', 'merch_lat', 'merch_long', 
                'age', 'trans_hour', 'trans_day', 'trans_month', 'trans_dayofweek']
cat_features = ['merchant', 'category', 'gender', 'street', 'city', 'state', 'zip', 'job']

# Convert y_train to Series (assuming the first column is the target)
y_train = y_train_df.iloc[:, 0]

# Create boolean masks for fraud (target==1) and non-fraud (target==0)
fraud_mask = (y_train == 1)
nonfraud_mask = (y_train == 0)

# Split X_train_df into numeric and categorical parts:
# (Assuming numerical features are already normalized and saved accordingly,
#  and categorical features are integer codes)
X_train_num = X_train_df[num_features].loc[fraud_mask].values
X_train_cat = X_train_df[cat_features].loc[fraud_mask].values

# For computing the adaptive non-fraud prior (probability-based loss),
# load non-fraud numeric features:
X_nonfraud_num = X_train_df[num_features].loc[nonfraud_mask].values
# Out:
# Loaded transformation artifacts from Data/processed.

# %%
cat_vocab
# Out:
# {'merchant': 693,
#  'category': 14,
#  'gender': 2,
#  'street': 999,
#  'city': 906,
#  'state': 51,
#  'zip': 985,
#  'job': 497}

# %%
cat_mapping
# Out:
# {'merchant': {'fraud_Rippin, Kub and Mann': 0,
#   'fraud_Heller, Gutmann and Zieme': 1,
#   'fraud_Lind-Buckridge': 2,
#   'fraud_Kutch, Hermiston and Farrell': 3,
#   'fraud_Keeling-Crist': 4,
#   'fraud_Stroman, Hudson and Erdman': 5,
#   'fraud_Rowe-Vandervort': 6,
#   'fraud_Corwin-Collins': 7,
#   'fraud_Herzog Ltd': 8,
#   'fraud_Schoen, Kuphal and Nitzsche': 9,
#   'fraud_Rutherford-Mertz': 10,
#   'fraud_Kerluke-Abshire': 11,
#   'fraud_Lockman Ltd': 12,
#   'fraud_Kiehn Inc': 13,
#   'fraud_Beier-Hyatt': 14,
#   'fraud_Schmidt and Sons': 15,
#   'fraud_Lebsack and Sons': 16,
#   'fraud_Mayert Group': 17,
#   'fraud_Konopelski, Schneider and Hartmann': 18,
#   'fraud_Schultz, Simonis and Little': 19,
#   'fraud_Bauch-Raynor': 20,
#   'fraud_Harris Inc': 21,
#   'fraud_Kling-Grant': 22,
#   'fraud_Pacocha-Bauch': 23,
#   'fraud_Lesch Ltd': 24,
#   'fraud_Kunde-Sanford': 25,
#   "fraud_Deckow-O'Conner": 26,
#   'fraud_Bruen-Yost': 27,
#   'fraud_Kunze Inc': 28,
#   'fraud_Nitzsche, Kessler and Wolff': 29,
#   'fraud_Kihn, Abernathy and Douglas': 30,
#   'fraud_Torphy-Goyette': 31,
#   'fraud_Balistreri-Nader': 32,
#   'fraud_Bahringer, Schoen and Corkery': 33,
#   'fraud_Hudson-Ratke': 34,
#   'fraud_Heidenreich PLC': 35,
#   'fraud_Halvorson Group': 36,
#   'fraud_Harber Inc': 37,
#   'fraud_Mosciski, Gislason and Mertz': 38,
#   'fraud_Christiansen, Goyette and Schamberger': 39,
#   'fraud_Howe Ltd': 40,
#   'fraud_Ledner-Pfannerstill': 41,
#   'fraud_Koepp-Witting': 42,
#   'fraud_Doyle Ltd': 43,
#   'fraud_Schaefer, Maggio and Daugherty': 44,
#   'fraud_Stracke-Lemke': 45,
#   'fraud_Mosciski, Ziemann and Farrell': 46,
#   'fraud_Cartwright-Harris': 47,
#   "fraud_Pacocha-O'Reilly": 48,
#   'fraud_Pfeffer LLC': 49,
#   'fraud_Huels-Hahn': 50,
#   'fraud_Volkman PLC': 51,
#   'fraud_Kiehn-Emmerich': 52,
#   'fraud_Kemmer-Buckridge': 53,
#   'fraud_Cummerata-Jones': 54,
#   'fraud_Goldner, Kovacek and Abbott': 55,
#   'fraud_Spinka-Welch': 56,
#   'fraud_Huel-Langworth': 57,
#   'fraud_Macejkovic-Lesch': 58,
#   'fraud_Morar Inc': 59,
#   'fraud_Eichmann, Bogan and Rodriguez': 60,
#   'fraud_Huel, Hammes and Witting': 61,
#   'fraud_Ferry, Lynch and Kautzer': 62,
#   'fraud_Heathcote LLC': 63,
#   'fraud_Little, Gutmann and Lynch': 64,
#   'fraud_Jaskolski-Dibbert': 65,
#   'fraud_Hackett-Lueilwitz': 66,
#   'fraud_Cummings LLC': 67,
#   'fraud_Swaniawski, Lowe and Robel': 68,
#   'fraud_Osinski, Ledner and Leuschke': 69,
#   'fraud_Reichert, Huels and Hoppe': 70,
#   'fraud_Ankunding LLC': 71,
#   'fraud_Pfeffer and Sons': 72,
#   'fraud_Greenholt, Jacobi and Gleason': 73,
#   'fraud_Connelly, Reichert and Fritsch': 74,
#   'fraud_Torp-Labadie': 75,
#   'fraud_Wolf Inc': 76,
#   'fraud_VonRueden Group': 77,
#   'fraud_Vandervort-Funk': 78,
#   'fraud_Bernhard Inc': 79,
#   'fraud_Morissette, Weber and Wiegand': 80,
#   'fraud_Brekke and Sons': 81,
#   'fraud_Mraz-Herzog': 82,
#   'fraud_Padberg-Welch': 83,
#   'fraud_Kutch-Hegmann': 84,
#   'fraud_Corwin-Gorczany': 85,
#   'fraud_Huels-Nolan': 86,
#   'fraud_DuBuque LLC': 87,
#   'fraud_Schmeler Inc': 88,
#   'fraud_Schaefer, McGlynn and Bosco': 89,
#   'fraud_Williamson LLC': 90,
#   'fraud_Pouros-Conroy': 91,
#   'fraud_Erdman-Kertzmann': 92,
#   'fraud_Kuhn LLC': 93,
#   'fraud_Fisher-Schowalter': 94,
#   'fraud_Medhurst PLC': 95,
#   'fraud_Kerluke Inc': 96,
#   'fraud_Stark-Batz': 97,
#   'fraud_Gottlieb, Considine and Schultz': 98,
#   'fraud_Adams, Kovacek and Kuhlman': 99,
#   'fraud_Grimes LLC': 100,
#   'fraud_Rodriguez Group': 101,
#   'fraud_Wuckert-Walter': 102,
#   'fraud_Weber and Sons': 103,
#   'fraud_Herman, Treutel and Dickens': 104,
#   'fraud_Rau and Sons': 105,
#   'fraud_Koss and Sons': 106,
#   'fraud_Smitham-Schiller': 107,
#   'fraud_Hills-Olson': 108,
#   'fraud_Durgan-Auer': 109,
#   'fraud_McDermott-Rice': 110,
#   'fraud_Raynor, Reinger and Hagenes': 111,
#   'fraud_Powlowski-Weimann': 112,
#   'fraud_Langosh, Wintheiser and Hyatt': 113,
#   'fraud_Baumbach, Hodkiewicz and Walsh': 114,
#   'fraud_Rempel Inc': 115,
#   'fraud_Bins-Rice': 116,
#   'fraud_Emard Inc': 117,
#   'fraud_Kutch and Sons': 118,
#   'fraud_Fisher Inc': 119,
#   'fraud_Olson, Becker and Koch': 120,
#   "fraud_Friesen-D'Amore": 121,
#   'fraud_Reilly, Heaney and Cole': 122,
#   'fraud_Boyer PLC': 123,
#   'fraud_Luettgen PLC': 124,
#   'fraud_Cassin-Harvey': 125,
#   'fraud_Funk Group': 126,
#   'fraud_Goodwin-Nitzsche': 127,
#   'fraud_Parisian, Schiller and Altenwerth': 128,
#   'fraud_Metz-Boehm': 129,
#   'fraud_Monahan, Bogisich and Ledner': 130,
#   'fraud_Koelpin and Sons': 131,
#   'fraud_Kuhic LLC': 132,
#   'fraud_Koepp-Parker': 133,
#   'fraud_Stehr, Jewess and Schimmel': 134,
#   'fraud_Quitzon, Green and Bashirian': 135,
#   'fraud_Nicolas, Hills and McGlynn': 136,
#   'fraud_Leannon-Ward': 137,
#   'fraud_Friesen-Stamm': 138,
#   'fraud_Botsford Ltd': 139,
#   'fraud_Bradtke PLC': 140,
#   'fraud_Zieme, Bode and Dooley': 141,
#   'fraud_Hills-Witting': 142,
#   'fraud_Brown-Greenholt': 143,
#   'fraud_Bernhard, Grant and Langworth': 144,
#   'fraud_Wiza, Schaden and Stark': 145,
#   'fraud_Buckridge PLC': 146,
#   'fraud_Kilback LLC': 147,
#   'fraud_Spinka Inc': 148,
#   'fraud_Kerluke, Kertzmann and Wiza': 149,
#   'fraud_Ferry, Reichel and DuBuque': 150,
#   'fraud_Price Inc': 151,
#   'fraud_Johnston, Nikolaus and Maggio': 152,
#   'fraud_Berge LLC': 153,
#   'fraud_Conroy-Cruickshank': 154,
#   'fraud_Abshire PLC': 155,
#   'fraud_Gleason-Macejkovic': 156,
#   'fraud_McGlynn-Jaskolski': 157,
#   'fraud_Bartoletti-Wunsch': 158,
#   'fraud_Cole PLC': 159,
#   'fraud_Lehner, Reichert and Mills': 160,
#   'fraud_McCullough LLC': 161,
#   'fraud_Schmitt Ltd': 162,
#   'fraud_Pouros-Haag': 163,
#   'fraud_Strosin-Cruickshank': 164,
#   'fraud_Weimann, Kuhic and Beahan': 165,
#   'fraud_Donnelly PLC': 166,
#   'fraud_Lockman, West and Runte': 167,
#   'fraud_Torp-Lemke': 168,
#   'fraud_Kris-Weimann': 169,
#   'fraud_Rodriguez, Yost and Jenkins': 170,
#   'fraud_Wiegand-Lowe': 171,
#   'fraud_Auer-Mosciski': 172,
#   'fraud_Okuneva, Schneider and Rau': 173,
#   'fraud_Kassulke PLC': 174,
#   'fraud_Dach-Nader': 175,
#   'fraud_Cummings Group': 176,
#   'fraud_Reichert, Shanahan and Hayes': 177,
#   'fraud_Tromp, Kerluke and Glover': 178,
#   'fraud_Bins, Balistreri and Beatty': 179,
#   'fraud_Trantow PLC': 180,
#   'fraud_Miller-Hauck': 181,
#   'fraud_Kuvalis Ltd': 182,
#   'fraud_Dickinson Ltd': 183,
#   'fraud_Stanton, Jakubowski and Baumbach': 184,
#   'fraud_Rohan, White and Aufderhar': 185,
#   'fraud_Cormier, Stracke and Thiel': 186,
#   'fraud_Tillman, Fritsch and Schmitt': 187,
#   'fraud_Christiansen-Gusikowski': 188,
#   'fraud_Jenkins, Hauck and Friesen': 189,
#   'fraud_Reichel Inc': 190,
#   'fraud_Prohaska-Murray': 191,
#   'fraud_Parker, Nolan and Trantow': 192,
#   'fraud_Volkman Ltd': 193,
#   'fraud_Streich, Hansen and Veum': 194,
#   'fraud_Kutch LLC': 195,
#   'fraud_Barton Inc': 196,
#   'fraud_Dooley-Thompson': 197,
#   'fraud_Flatley Group': 198,
#   'fraud_Turcotte-Halvorson': 199,
#   'fraud_Lynch Ltd': 200,
#   'fraud_Romaguera, Cruickshank and Greenholt': 201,
#   'fraud_Gutmann Ltd': 202,
#   'fraud_Sporer Inc': 203,
#   'fraud_Runolfsson and Sons': 204,
#   'fraud_Block Group': 205,
#   'fraud_Bahringer-Larson': 206,
#   'fraud_Rowe, Batz and Goodwin': 207,
#   'fraud_Schmitt Inc': 208,
#   'fraud_Maggio-Fahey': 209,
#   'fraud_Haley, Jewess and Bechtelar': 210,
#   'fraud_Ruecker, Beer and Collier': 211,
#   'fraud_Robel, Cummerata and Prosacco': 212,
#   'fraud_Jast-McDermott': 213,
#   'fraud_Bernier, Volkman and Hoeger': 214,
#   'fraud_Heaney-Marquardt': 215,
#   'fraud_Hudson-Grady': 216,
#   'fraud_Towne, Walker and Borer': 217,
#   'fraud_Terry-Huel': 218,
#   'fraud_Kihn-Fritsch': 219,
#   'fraud_Eichmann-Russel': 220,
#   'fraud_Miller-Harris': 221,
#   'fraud_Schumm PLC': 222,
#   'fraud_Greenfelder, Bartoletti and Davis': 223,
#   'fraud_Kovacek, Dibbert and Ondricka': 224,
#   'fraud_Hermann-Gaylord': 225,
#   'fraud_Bailey-Morar': 226,
#   'fraud_McDermott-Weimann': 227,
#   'fraud_Welch Inc': 228,
#   'fraud_Auer-West': 229,
#   'fraud_Boehm, Predovic and Reinger': 230,
#   'fraud_Dibbert and Sons': 231,
#   'fraud_Lind, Huel and McClure': 232,
#   'fraud_Casper, Hand and Zulauf': 233,
#   'fraud_McCullough Group': 234,
#   'fraud_Streich, Dietrich and Barton': 235,
#   "fraud_O'Keefe-Hudson": 236,
#   'fraud_Pagac LLC': 237,
#   'fraud_Bernier, Streich and Jewess': 238,
#   "fraud_Greenholt, O'Hara and Balistreri": 239,
#   'fraud_Dickinson-Rempel': 240,
#   'fraud_Dare-Marvin': 241,
#   'fraud_Spencer PLC': 242,
#   'fraud_Stamm-Rodriguez': 243,
#   'fraud_Langworth, Boehm and Gulgowski': 244,
#   'fraud_Larkin, Stracke and Greenfelder': 245,
#   'fraud_Yost, Block and Koepp': 246,
#   'fraud_Douglas, Schneider and Turner': 247,
#   'fraud_Kuphal-Predovic': 248,
#   'fraud_Parisian and Sons': 249,
#   'fraud_Flatley-Durgan': 250,
#   'fraud_Gislason Group': 251,
#   'fraud_Bednar Group': 252,
#   'fraud_Heller-Langosh': 253,
#   'fraud_Zboncak Ltd': 254,
#   'fraud_Gerlach Inc': 255,
#   'fraud_Wilkinson Ltd': 256,
#   'fraud_Moen, Reinger and Murphy': 257,
#   'fraud_Kerluke, Considine and Macejkovic': 258,
#   'fraud_Upton PLC': 259,
#   'fraud_Bogisich Inc': 260,
#   'fraud_Marks Inc': 261,
#   'fraud_Murray-Smitham': 262,
#   'fraud_Frami Group': 263,
#   'fraud_Ortiz Group': 264,
#   'fraud_Goldner-Lemke': 265,
#   'fraud_Hickle Group': 266,
#   'fraud_Conroy Ltd': 267,
#   'fraud_Schumm, Bauch and Ondricka': 268,
#   'fraud_McGlynn-Heathcote': 269,
#   'fraud_Herman Inc': 270,
#   'fraud_Gutmann-Upton': 271,
#   'fraud_Volkman-Predovic': 272,
#   'fraud_Wintheiser, Dietrich and Schimmel': 273,
#   'fraud_Raynor, Feest and Miller': 274,
#   'fraud_Bogisich-Homenick': 275,
#   'fraud_Jast and Sons': 276,
#   'fraud_Baumbach, Strosin and Nicolas': 277,
#   'fraud_Towne, Greenholt and Koepp': 278,
#   "fraud_Schamberger-O'Keefe": 279,
#   'fraud_Nienow PLC': 280,
#   'fraud_Emmerich-Luettgen': 281,
#   'fraud_Mante Group': 282,
#   'fraud_Baumbach, Feeney and Morar': 283,
#   'fraud_Thiel PLC': 284,
#   'fraud_Mohr Inc': 285,
#   'fraud_Hagenes, Kohler and Hoppe': 286,
#   'fraud_Block-Parisian': 287,
#   'fraud_Dooley Inc': 288,
#   'fraud_Bashirian Group': 289,
#   'fraud_Cremin, Hamill and Reichel': 290,
#   'fraud_Sawayn PLC': 291,
#   'fraud_Jewess LLC': 292,
#   'fraud_Roberts-Beahan': 293,
#   'fraud_Brown PLC': 294,
#   'fraud_Tillman, Dickinson and Labadie': 295,
#   'fraud_Reichert, Rowe and Mraz': 296,
#   'fraud_Kilback Group': 297,
#   'fraud_Spencer-Runolfsson': 298,
#   'fraud_Labadie, Treutel and Bode': 299,
#   'fraud_Dach-Borer': 300,
#   'fraud_Johnson, Runolfsdottir and Mayer': 301,
#   'fraud_Smitham-Boehm': 302,
#   'fraud_Moore, Dibbert and Koepp': 303,
#   'fraud_Hamill-Daugherty': 304,
#   'fraud_Watsica, Haag and Considine': 305,
#   'fraud_Smith-Stokes': 306,
#   'fraud_Kuhic, Bins and Pfeffer': 307,
#   'fraud_Nader-Heller': 308,
#   'fraud_Kozey-Boehm': 309,
#   'fraud_Stiedemann Inc': 310,
#   'fraud_Lehner, Mosciski and King': 311,
#   'fraud_Reynolds-Schinner': 312,
#   'fraud_Koss, McLaughlin and Mayer': 313,
#   'fraud_Terry, Johns and Bins': 314,
#   'fraud_Kemmer-Reinger': 315,
#   'fraud_Larson-Moen': 316,
#   'fraud_Kuhic Inc': 317,
#   'fraud_Kris-Padberg': 318,
#   'fraud_Schmeler, Bashirian and Price': 319,
#   'fraud_Klocko LLC': 320,
#   'fraud_Schaefer, Fay and Hilll': 321,
#   'fraud_Kling Inc': 322,
#   'fraud_Turner and Sons': 323,
#   'fraud_Mohr-Bayer': 324,
#   'fraud_Wiza LLC': 325,
#   'fraud_Skiles-Ankunding': 326,
#   'fraud_Jaskolski-Vandervort': 327,
#   'fraud_Kerluke PLC': 328,
#   'fraud_Ernser-Lynch': 329,
#   'fraud_Zboncak, Rowe and Murazik': 330,
#   'fraud_Stoltenberg-Beatty': 331,
#   'fraud_Kuphal-Bartoletti': 332,
#   'fraud_Rempel PLC': 333,
#   'fraud_Denesik and Sons': 334,
#   'fraud_Goyette Inc': 335,
#   'fraud_Dicki Ltd': 336,
#   'fraud_Stokes, Christiansen and Sipes': 337,
#   'fraud_Hermann and Sons': 338,
#   'fraud_Gibson-Deckow': 339,
#   'fraud_Douglas-White': 340,
#   'fraud_Murray Ltd': 341,
#   'fraud_McKenzie-Huels': 342,
#   'fraud_Runte-Mohr': 343,
#   'fraud_Roob, Conn and Tremblay': 344,
#   'fraud_Boyer-Reichert': 345,
#   'fraud_Shanahan-Lehner': 346,
#   'fraud_Greenholt Ltd': 347,
#   'fraud_Kulas Group': 348,
#   'fraud_Dare, Fritsch and Zboncak': 349,
#   'fraud_Waters-Cruickshank': 350,
#   'fraud_Kunze, Larkin and Mayert': 351,
#   'fraud_Bednar Inc': 352,
#   'fraud_Schimmel-Olson': 353,
#   'fraud_Lubowitz, Terry and Stracke': 354,
#   'fraud_Schoen-Quigley': 355,
#   'fraud_Kihn-Schuster': 356,
#   'fraud_Padberg-Rogahn': 357,
#   'fraud_Lynch-Mohr': 358,
#   'fraud_Hilpert-Conroy': 359,
#   'fraud_Jacobi Inc': 360,
#   'fraud_Berge, Kautzer and Harris': 361,
#   'fraud_Hammes-Beatty': 362,
#   'fraud_Gulgowski LLC': 363,
#   'fraud_Schuppe, Nolan and Hoeger': 364,
#   'fraud_Pollich LLC': 365,
#   'fraud_Bernier and Sons': 366,
#   'fraud_Wilkinson PLC': 367,
#   'fraud_Kling-Ernser': 368,
#   "fraud_O'Connell, Botsford and Hand": 369,
#   'fraud_Little-Gleichner': 370,
#   'fraud_Champlin and Sons': 371,
#   'fraud_Hoppe-Parisian': 372,
#   'fraud_Schuppe LLC': 373,
#   'fraud_Emmerich-Rau': 374,
#   'fraud_Beier LLC': 375,
#   'fraud_Champlin-Casper': 376,
#   'fraud_Gerhold LLC': 377,
#   'fraud_Renner Ltd': 378,
#   'fraud_Gaylord-Powlowski': 379,
#   'fraud_Prosacco, Kreiger and Kovacek': 380,
#   'fraud_Eichmann-Kilback': 381,
#   "fraud_O'Hara-Wilderman": 382,
#   'fraud_Terry Ltd': 383,
#   'fraud_Beier and Sons': 384,
#   "fraud_O'Keefe-Wisoky": 385,
#   'fraud_Simonis-Prohaska': 386,
#   'fraud_Breitenberg-Hermiston': 387,
#   'fraud_Brown Inc': 388,
#   'fraud_Fahey Inc': 389,
#   'fraud_Boehm, Block and Jakubowski': 390,
#   'fraud_Mante, Luettgen and Hackett': 391,
#   'fraud_Thompson-Gleason': 392,
#   'fraud_Turcotte, Batz and Buckridge': 393,
#   'fraud_Goyette, Howell and Collier': 394,
#   'fraud_Jones, Sawayn and Romaguera': 395,
#   'fraud_Medhurst Inc': 396,
#   'fraud_Bode-Schuster': 397,
#   'fraud_Connelly-Carter': 398,
#   'fraud_Gottlieb-Hansen': 399,
#   'fraud_Schroeder, Wolff and Hermiston': 400,
#   'fraud_Hettinger, McCullough and Fay': 401,
#   'fraud_Pouros, Walker and Spencer': 402,
#   'fraud_Kub PLC': 403,
#   'fraud_Watsica LLC': 404,
#   'fraud_Stiedemann Ltd': 405,
#   'fraud_Hauck, Dietrich and Funk': 406,
#   'fraud_Labadie LLC': 407,
#   'fraud_Friesen Inc': 408,
#   'fraud_Crist, Jakubowski and Littel': 409,
#   'fraud_Hodkiewicz, Prohaska and Paucek': 410,
#   'fraud_McDermott, Osinski and Morar': 411,
#   'fraud_Fritsch and Sons': 412,
#   'fraud_Swaniawski, Nitzsche and Welch': 413,
#   'fraud_Windler, Goodwin and Kovacek': 414,
#   'fraud_Yost, Schamberger and Windler': 415,
#   'fraud_Metz, Russel and Metz': 416,
#   'fraud_Erdman-Durgan': 417,
#   'fraud_Bahringer, Bergnaum and Quitzon': 418,
#   'fraud_Veum-Koelpin': 419,
#   'fraud_Becker, Harris and Harvey': 420,
#   'fraud_Monahan-Morar': 421,
#   'fraud_Johns Inc': 422,
#   'fraud_Mosciski Group': 423,
#   'fraud_Abbott-Steuber': 424,
#   'fraud_Schaefer Ltd': 425,
#   'fraud_Dibbert-Green': 426,
#   'fraud_Weimann-Lockman': 427,
#   'fraud_Kub-Heaney': 428,
#   'fraud_Zulauf LLC': 429,
#   'fraud_Ratke and Sons': 430,
#   'fraud_Jakubowski Inc': 431,
#   'fraud_Beer-Jast': 432,
#   'fraud_Kautzer and Sons': 433,
#   'fraud_Feil-Morar': 434,
#   'fraud_Johnston-Casper': 435,
#   'fraud_Medhurst, Labadie and Gottlieb': 436,
#   "fraud_Lesch, D'Amore and Brown": 437,
#   'fraud_Botsford PLC': 438,
#   'fraud_Bins-Howell': 439,
#   'fraud_Kihn Inc': 440,
#   'fraud_Hartmann, Rowe and Hermann': 441,
#   'fraud_Towne LLC': 442,
#   'fraud_Lynch-Wisozk': 443,
#   'fraud_Kutch-Ferry': 444,
#   'fraud_Goyette-Gerhold': 445,
#   'fraud_Bradtke, Torp and Bahringer': 446,
#   'fraud_Homenick LLC': 447,
#   'fraud_Zemlak, Tillman and Cremin': 448,
#   'fraud_Schneider, Hayes and Nikolaus': 449,
#   'fraud_Schumm, McLaughlin and Carter': 450,
#   'fraud_Nader-Maggio': 451,
#   'fraud_Haley, Batz and Auer': 452,
#   'fraud_Yost-Rogahn': 453,
#   'fraud_Schoen, Nienow and Bauch': 454,
#   'fraud_Ledner, Hartmann and Feest': 455,
#   'fraud_Collier LLC': 456,
#   'fraud_Schuppe-Schuppe': 457,
#   'fraud_Walter, Hettinger and Kessler': 458,
#   'fraud_Bechtelar-Rippin': 459,
#   "fraud_Hamill-D'Amore": 460,
#   'fraud_Swift PLC': 461,
#   'fraud_Cronin, Kshlerin and Weber': 462,
#   'fraud_Romaguera, Wehner and Tromp': 463,
#   'fraud_Feil, Hilpert and Koss': 464,
#   'fraud_White and Sons': 465,
#   'fraud_Mueller, Gerhold and Mueller': 466,
#   'fraud_Botsford and Sons': 467,
#   'fraud_Kirlin and Sons': 468,
#   'fraud_Bednar PLC': 469,
#   'fraud_Runolfsdottir, Mueller and Hand': 470,
#   'fraud_Kuphal-Toy': 471,
#   'fraud_Bahringer-Streich': 472,
#   'fraud_Wuckert, Wintheiser and Friesen': 473,
#   'fraud_Crona and Sons': 474,
#   'fraud_Prosacco LLC': 475,
#   'fraud_Schiller Ltd': 476,
#   'fraud_Waelchi-Wolf': 477,
#   'fraud_Torphy-Kertzmann': 478,
#   'fraud_McCullough, Hudson and Schuster': 479,
#   'fraud_Baumbach Ltd': 480,
#   'fraud_Schiller, Blanda and Johnson': 481,
#   'fraud_Cartwright PLC': 482,
#   'fraud_Reilly LLC': 483,
#   'fraud_Cruickshank-Mills': 484,
#   'fraud_Altenwerth, Cartwright and Koss': 485,
#   'fraud_Effertz, Welch and Schowalter': 486,
#   'fraud_Klocko, Runolfsdottir and Breitenberg': 487,
#   'fraud_Ruecker-Mayert': 488,
#   'fraud_Schroeder, Hauck and Treutel': 489,
#   'fraud_Lemke-Gutmann': 490,
#   'fraud_Graham, Hegmann and Hammes': 491,
#   'fraud_Reilly and Sons': 492,
#   'fraud_Stark-Koss': 493,
#   'fraud_Daugherty LLC': 494,
#   'fraud_Denesik, Powlowski and Pouros': 495,
#   'fraud_Rippin-VonRueden': 496,
#   'fraud_Heller PLC': 497,
#   'fraud_Hills-Boyer': 498,
#   'fraud_Cormier LLC': 499,
#   'fraud_Erdman-Ebert': 500,
#   'fraud_Bogisich-Weimann': 501,
#   'fraud_Gutmann, McLaughlin and Wiza': 502,
#   'fraud_Little Ltd': 503,
#   'fraud_Bode-Rempel': 504,
#   'fraud_Kutch, Steuber and Gerhold': 505,
#   'fraud_Kessler Inc': 506,
#   'fraud_Deckow-Dare': 507,
#   'fraud_Rolfson-Kunde': 508,
#   'fraud_Marvin-Lind': 509,
#   'fraud_Barrows PLC': 510,
#   'fraud_Abbott-Rogahn': 511,
#   'fraud_Ziemann-Waters': 512,
#   'fraud_Reinger, Weissnat and Strosin': 513,
#   'fraud_Heathcote, Yost and Kertzmann': 514,
#   'fraud_Will Ltd': 515,
#   'fraud_Kutch-Wilderman': 516,
#   'fraud_Hermiston, Russel and Price': 517,
#   'fraud_Schmidt-Larkin': 518,
#   'fraud_Lang, Towne and Schuppe': 519,
#   'fraud_Weber, Thiel and Hammes': 520,
#   'fraud_Hahn, Bahringer and McLaughlin': 521,
#   'fraud_Koss, Hansen and Lueilwitz': 522,
#   'fraud_Roberts, Ryan and Smith': 523,
#   'fraud_Hintz, Bauch and Smith': 524,
#   'fraud_Monahan, Hermann and Johns': 525,
#   'fraud_Bahringer, Osinski and Block': 526,
#   'fraud_Douglas, DuBuque and McKenzie': 527,
#   'fraud_Hackett Group': 528,
#   'fraud_Schmeler-Howe': 529,
#   'fraud_Predovic Inc': 530,
#   'fraud_Langworth LLC': 531,
#   'fraud_Bartoletti and Sons': 532,
#   'fraud_Bernhard-Lesch': 533,
#   'fraud_Satterfield-Lowe': 534,
#   'fraud_Runte, Green and Emard': 535,
#   'fraud_Lowe, Dietrich and Erdman': 536,
#   'fraud_Jast Ltd': 537,
#   'fraud_Welch, Rath and Koepp': 538,
#   'fraud_Skiles LLC': 539,
#   'fraud_Ernser-Feest': 540,
#   'fraud_Klein Group': 541,
#   'fraud_Torp, Muller and Borer': 542,
#   'fraud_Kuhn Group': 543,
#   'fraud_Streich, Rolfson and Wilderman': 544,
#   'fraud_Bins-Tillman': 545,
#   'fraud_Ankunding-Carroll': 546,
#   'fraud_Hahn, Douglas and Schowalter': 547,
#   'fraud_Witting, Beer and Ernser': 548,
#   'fraud_Morissette LLC': 549,
#   'fraud_Berge-Hills': 550,
#   'fraud_Donnelly LLC': 551,
#   'fraud_Zboncak LLC': 552,
#   'fraud_Turner, Ziemann and Lehner': 553,
#   'fraud_Padberg-Sauer': 554,
#   'fraud_Schulist Ltd': 555,
#   'fraud_Rau-Grant': 556,
#   'fraud_Osinski Inc': 557,
#   'fraud_Berge-Ullrich': 558,
#   'fraud_Wuckert-Goldner': 559,
#   'fraud_Kertzmann LLC': 560,
#   'fraud_Daugherty, Pouros and Beahan': 561,
#   'fraud_Armstrong, Walter and Gottlieb': 562,
#   'fraud_Conroy-Emard': 563,
#   'fraud_Moore, Williamson and Emmerich': 564,
#   'fraud_Gleason and Sons': 565,
#   'fraud_Roberts, Daniel and Macejkovic': 566,
#   'fraud_Turner LLC': 567,
#   'fraud_Crooks and Sons': 568,
#   'fraud_Waelchi Inc': 569,
#   'fraud_Hoppe, Harris and Bednar': 570,
#   'fraud_Effertz LLC': 571,
#   'fraud_Lubowitz-Walter': 572,
#   'fraud_Hyatt-Blick': 573,
#   'fraud_Carroll PLC': 574,
#   'fraud_Lemke and Sons': 575,
#   'fraud_Treutel-King': 576,
#   'fraud_Fadel-Hilpert': 577,
#   'fraud_Altenwerth-Kilback': 578,
#   'fraud_Bauch-Blanda': 579,
#   'fraud_Sporer-Keebler': 580,
#   'fraud_Hirthe-Beier': 581,
#   'fraud_Wisozk and Sons': 582,
#   'fraud_Streich Ltd': 583,
#   'fraud_Schoen Ltd': 584,
#   'fraud_Windler LLC': 585,
#   'fraud_Nolan-Williamson': 586,
#   'fraud_Roob-Okuneva': 587,
#   'fraud_Lakin, Ferry and Beatty': 588,
#   'fraud_Gottlieb Group': 589,
#   'fraud_Harris Group': 590,
#   'fraud_Fritsch LLC': 591,
#   'fraud_Corwin-Romaguera': 592,
#   'fraud_Dietrich-Fadel': 593,
#   'fraud_Kling, Howe and Schneider': 594,
#   'fraud_Kozey-Kuhlman': 595,
#   'fraud_Graham and Sons': 596,
#   'fraud_Jacobi and Sons': 597,
#   'fraud_Eichmann, Hayes and Treutel': 598,
#   'fraud_Brown, Homenick and Lesch': 599,
#   'fraud_Erdman-Schaden': 600,
#   'fraud_Durgan, Gislason and Spencer': 601,
#   'fraud_Friesen-Ortiz': 602,
#   'fraud_Morissette-Schaefer': 603,
#   'fraud_Nienow, Ankunding and Collier': 604,
#   'fraud_Cole, Hills and Jewess': 605,
#   'fraud_Conroy, Balistreri and Gorczany': 606,
#   'fraud_Reichel, Bradtke and Blanda': 607,
#   "fraud_O'Reilly, Mohr and Purdy": 608,
#   'fraud_Ullrich Ltd': 609,
#   'fraud_Schroeder Group': 610,
#   'fraud_Boyer-Haley': 611,
#   'fraud_Dare, Casper and Bartoletti': 612,
#   'fraud_Medhurst, Cartwright and Ebert': 613,
#   'fraud_Quitzon-Goyette': 614,
#   'fraud_Wilkinson LLC': 615,
#   'fraud_Romaguera and Sons': 616,
#   'fraud_Larkin Ltd': 617,
#   'fraud_Fadel, Mertz and Rippin': 618,
#   'fraud_Huel Ltd': 619,
#   'fraud_Cummerata-Hilpert': 620,
#   'fraud_Zemlak Group': 621,
#   'fraud_Dare-Gibson': 622,
#   'fraud_Adams-Barrows': 623,
#   'fraud_Block-Hauck': 624,
#   'fraud_Howe PLC': 625,
#   'fraud_Leffler-Goldner': 626,
#   'fraud_Tillman LLC': 627,
#   'fraud_Pacocha-Weissnat': 628,
#   'fraud_Morissette PLC': 629,
#   'fraud_Jerde-Hermann': 630,
#   'fraud_Kihn, Brakus and Goyette': 631,
#   'fraud_Hills, Hegmann and Schaefer': 632,
#   'fraud_Friesen Ltd': 633,
#   'fraud_Kilback and Sons': 634,
#   'fraud_Ebert-Daugherty': 635,
#   'fraud_Hermiston, Pacocha and Smith': 636,
#   'fraud_Auer LLC': 637,
#   'fraud_Fadel Inc': 638,
#   'fraud_Daugherty-Thompson': 639,
#   'fraud_Romaguera Ltd': 640,
#   'fraud_Parker-Kunde': 641,
#   'fraud_Barton LLC': 642,
#   'fraud_Kassulke Inc': 643,
#   'fraud_McLaughlin, Armstrong and Koepp': 644,
#   'fraud_Abernathy and Sons': 645,
#   'fraud_Bahringer Group': 646,
#   'fraud_Connelly PLC': 647,
#   'fraud_Willms, Kris and Bergnaum': 648,
#   'fraud_Thiel Ltd': 649,
#   'fraud_Kris-Kertzmann': 650,
#   "fraud_O'Connell-Ullrich": 651,
#   'fraud_Kozey-McDermott': 652,
#   'fraud_Reichel LLC': 653,
#   'fraud_Thiel-Thiel': 654,
#   'fraud_Rau-Robel': 655,
#   'fraud_Haley Group': 656,
#   'fraud_Turcotte, McKenzie and Koss': 657,
#   'fraud_Stamm-Witting': 658,
#   'fraud_Ritchie, Bradtke and Stiedemann': 659,
#   'fraud_Nienow, Barrows and Romaguera': 660,
#   'fraud_Shields-Wunsch': 661,
#   'fraud_Goyette-Herzog': 662,
#   'fraud_Shields Inc': 663,
#   'fraud_Hayes, Marquardt and Dibbert': 664,
#   'fraud_Swaniawski, Bahringer and Ledner': 665,
#   'fraud_Roob LLC': 666,
#   'fraud_Rutherford, Homenick and Bergstrom': 667,
#   'fraud_Harris, Gusikowski and Heaney': 668,
#   'fraud_Hintz-Bruen': 669,
#   'fraud_Turner, Ruecker and Parisian': 670,
#   'fraud_Ruecker Group': 671,
#   'fraud_Johns-Hoeger': 672,
#   'fraud_Ritchie, Oberbrunner and Cremin': 673,
#   'fraud_Haag-Blanda': 674,
#   'fraud_Hagenes, Hermann and Stroman': 675,
#   'fraud_Reichert-Weissnat': 676,
#   'fraud_Hyatt, Russel and Gleichner': 677,
#   'fraud_Champlin, Rolfson and Connelly': 678,
#   'fraud_Leannon-Nikolaus': 679,
#   'fraud_Tromp Group': 680,
#   'fraud_Kovacek Ltd': 681,
#   'fraud_Kutch Group': 682,
#   'fraud_Kohler, Lindgren and Koelpin': 683,
#   'fraud_Heller-Abshire': 684,
#   'fraud_Swift, Bradtke and Marquardt': 685,
#   'fraud_Larson, Quitzon and Spencer': 686,
#   'fraud_Kilback, Nitzsche and Leffler': 687,
#   'fraud_Jakubowski Group': 688,
#   'fraud_Breitenberg LLC': 689,
#   'fraud_Collier Inc': 690,
#   'fraud_Paucek-Wiza': 691,
#   'fraud_Kessler Group': 692},
#  'category': {'misc_net': 0,
#   'grocery_pos': 1,
#   'entertainment': 2,
#   'gas_transport': 3,
#   'misc_pos': 4,
#   'grocery_net': 5,
#   'shopping_net': 6,
#   'shopping_pos': 7,
#   'food_dining': 8,
#   'personal_care': 9,
#   'health_fitness': 10,
#   'travel': 11,
#   'kids_pets': 12,
#   'home': 13},
#  'gender': {'F': 0, 'M': 1},
#  'street': {'561 Perry Cove': 0,
#   '43039 Riley Greens Suite 393': 1,
#   '594 White Dale Suite 530': 2,
#   '9443 Cynthia Court Apt. 038': 3,
#   '408 Bradley Rest': 4,
#   '4655 David Island': 5,
#   '889 Sarah Station Suite 624': 6,
#   '231 Flores Pass Suite 720': 7,
#   '6888 Hicks Stream Suite 954': 8,
#   '21326 Taylor Squares Suite 708': 9,
#   '1831 Faith View Suite 653': 10,
#   '43576 Kristina Islands': 11,
#   '3337 Lisa Divide': 12,
#   '5916 Susan Bridge Apt. 939': 13,
#   '1632 Cohen Drive Suite 639': 14,
#   '870 Rocha Drive': 15,
#   '44259 Beth Station Suite 215': 16,
#   '4923 Campbell Pines Suite 717': 17,
#   '268 Hayes Rue Suite 811': 18,
#   '269 Sanchez Rapids': 19,
#   '4005 Dana Glens': 20,
#   '21447 Powell Circle': 21,
#   '2481 Mills Lock': 22,
#   '759 Erin Mount Suite 956': 23,
#   '7683 Natasha Way Apt. 945': 24,
#   '551 Zachary Freeway': 25,
#   '61390 Hayes Port': 26,
#   '7483 Navarro Flats': 27,
#   '2711 Duran Pines': 28,
#   '969 Huerta Path Apt. 270': 29,
#   '57887 Gutierrez Harbor': 30,
#   '39787 Pamela Fall Suite 639': 31,
#   '445 Jerry Lights Apt. 081': 32,
#   '50872 Alex Plain Suite 088': 33,
#   '20937 Reed Lakes Apt. 271': 34,
#   '61107 Edwards Dam Apt. 463': 35,
#   '9333 Valentine Point': 36,
#   '742 Oneill Shore': 37,
#   '41851 Victor Drives Suite 219': 38,
#   '77321 Ford Via': 39,
#   '3645 Atkins Island Apt. 238': 40,
#   '213 Gill Expressway': 41,
#   '320 Nicholson Orchard': 42,
#   '35440 Ryan Islands': 43,
#   '242 Brian Mountain': 44,
#   '8957 Russell Key': 45,
#   '7202 Jeffrey Mills': 46,
#   '702 Tabitha Drive': 47,
#   '3789 Mark Walks': 48,
#   '68248 Deanna Land': 49,
#   '6447 Johnson Estates Apt. 986': 50,
#   '7369 Gabriel Tunnel': 51,
#   '4440 George Mills Suite 591': 52,
#   '358 Pruitt Square': 53,
#   '537 Walker Freeway': 54,
#   '31493 Garcia Summit': 55,
#   '0881 Lori Pines': 56,
#   '7566 Thompson Creek Apt. 827': 57,
#   '165 Jerry Meadows Suite 460': 58,
#   '212 Mary Stream': 59,
#   '493 Todd Views': 60,
#   '854 Walker Dale Suite 488': 61,
#   '11014 Chad Lake Apt. 573': 62,
#   '44864 Melton Vista Suite 310': 63,
#   '04611 Sandra Spring Suite 059': 64,
#   '9016 Jordan Bypass Apt. 516': 65,
#   '5812 Ramos Oval Suite 598': 66,
#   '29156 Mark Park Apt. 108': 67,
#   '864 Reynolds Plains': 68,
#   '0611 Stafford Valley Suite 504': 69,
#   '06959 Stephen Branch Suite 246': 70,
#   '05597 Michael Spurs': 71,
#   '144 Martinez Curve': 72,
#   '45654 Hess Rest': 73,
#   '433 John Heights Apt. 849': 74,
#   '62130 Miller Square Suite 785': 75,
#   '37910 Ward Lights': 76,
#   '273 Phillip Throughway': 77,
#   '658 Diane Glen Apt. 677': 78,
#   '7854 Stephanie Island Suite 788': 79,
#   '3379 Williams Common': 80,
#   '29606 Martinez Views Suite 653': 81,
#   '624 Hale Springs Apt. 572': 82,
#   '0069 Robin Brooks Apt. 695': 83,
#   '8738 Richard Brooks': 84,
#   '0182 Owens Burgs Suite 480': 85,
#   '4664 Sanchez Common Suite 930': 86,
#   '1007 Colton Forks': 87,
#   '17547 Stephen Turnpike Apt. 846': 88,
#   '31472 Cody Place Suite 740': 89,
#   '74835 Garner Point': 90,
#   '519 Jerry Views': 91,
#   '5045 Emily Wall': 92,
#   '67210 Lori Creek': 93,
#   '244 Abbott Parkway': 94,
#   '2970 Flores Brooks': 95,
#   '494 Burke Ports': 96,
#   '2497 John Motorway Suite 922': 97,
#   '2027 Snyder Track': 98,
#   '641 Steven Mall Apt. 299': 99,
#   '022 Moore Island': 100,
#   '248 James Squares Apt. 838': 101,
#   '5884 Sandoval Square Apt. 371': 102,
#   '168 Michael Coves Suite 343': 103,
#   '7177 Steven Forges': 104,
#   '53696 Laura Radial': 105,
#   '0043 Henry Plaza': 106,
#   '755 Gardner Heights Apt. 420': 107,
#   '1893 Katie Tunnel': 108,
#   '16744 Campbell Wall Apt. 372': 109,
#   '950 Sheryl Spurs': 110,
#   '033 Tara Brook Suite 523': 111,
#   '7838 Jason Squares': 112,
#   '144 Yu Locks Apt. 754': 113,
#   '5069 Scott Pass Apt. 654': 114,
#   '908 Brooks Brook': 115,
#   '8925 Nicholas Points': 116,
#   '566 Megan Well': 117,
#   '3861 Anderson Ramp Apt. 536': 118,
#   '0356 Sarah Light': 119,
#   '34180 Lopez Plaza': 120,
#   '292 Lowe Dam Suite 858': 121,
#   '766 Potter Well': 122,
#   '137 Adam Dale': 123,
#   '4038 Smith Avenue': 124,
#   '793 Hooper Tunnel Suite 154': 125,
#   '838 Dan Haven Suite 003': 126,
#   '25955 Amy Via': 127,
#   '374 Christopher Ramp Suite 855': 128,
#   '2674 Bentley Radial': 129,
#   '62631 Ashley Ramp Apt. 965': 130,
#   '682 Mills Way Apt. 814': 131,
#   '901 Ariel Points': 132,
#   '663 Ramirez Trace Apt. 951': 133,
#   '1652 James Mews': 134,
#   '8415 Vaughn Squares Apt. 788': 135,
#   '77944 Daniels Valley Suite 921': 136,
#   '302 Christina Islands': 137,
#   '899 Michele View Suite 960': 138,
#   '4720 Anna Ways': 139,
#   '7428 Martinez Flats': 140,
#   '3703 Benson Wells': 141,
#   '6574 William Hill Apt. 375': 142,
#   '079 Chelsea Rest': 143,
#   '576 House Crossroad': 144,
#   '67089 Caitlin Meadow Apt. 905': 145,
#   '9379 Vanessa Run Apt. 400': 146,
#   '1499 Michael Rue': 147,
#   '598 Martin Pine Suite 365': 148,
#   '380 Martin Mission': 149,
#   '3539 Mckenzie Stream': 150,
#   '841 Cheryl Centers Suite 115': 151,
#   '686 Linda Rest': 152,
#   '7955 Allen Orchard Apt. 336': 153,
#   '7233 John Parks': 154,
#   '6638 Lucero Mill Suite 952': 155,
#   '0207 Griffith Plains Apt. 544': 156,
#   '2819 Luke Greens Suite 563': 157,
#   '7020 Doyle Stream Apt. 951': 158,
#   '13776 Hicks Plains': 159,
#   '529 Joshua Knoll Apt. 511': 160,
#   '49120 Regina Island Apt. 170': 161,
#   '7618 Gonzales Mission': 162,
#   '20581 Pena Walks': 163,
#   '240 Tracy Forges': 164,
#   '5745 Blair Locks': 165,
#   '6412 Elizabeth Gardens Suite 633': 166,
#   '821 Solis Points': 167,
#   '857 Aaron Circles Suite 398': 168,
#   '27823 Andrew Underpass Suite 948': 169,
#   '8011 Chapman Tunnel Apt. 568': 170,
#   '257 Victor Stravenue': 171,
#   '69608 Perez Mountain Apt. 006': 172,
#   '9134 Darryl Flat Suite 916': 173,
#   '26975 Richardson Mills Apt. 402': 174,
#   '13613 Hammond Ferry': 175,
#   '03512 Jackson Ports': 176,
#   '5204 Robinson Plaza Suite 897': 177,
#   '5278 Sarah Station Apt. 009': 178,
#   '6114 Adams Harbor Suite 096': 179,
#   '72269 Elizabeth Field Apt. 132': 180,
#   '47029 Jimmy Tunnel Apt. 106': 181,
#   '994 Livingston Extensions Suite 918': 182,
#   '920 Patrick Light': 183,
#   '5449 Brandi Heights Apt. 111': 184,
#   '526 Stacy Walks': 185,
#   '5939 Garcia Forges Suite 297': 186,
#   '713 Scott Pike Apt. 712': 187,
#   '84079 Thomas Burgs': 188,
#   '956 Sanchez Highway': 189,
#   '27386 Snyder Station': 190,
#   '9795 Lori Island Suite 346': 191,
#   '1497 West Gateway': 192,
#   '3160 Tina Estates Suite 234': 193,
#   '1898 Parker Fork Apt. 057': 194,
#   '782 Lee Crossing Apt. 209': 195,
#   '6611 Parrish Garden Apt. 428': 196,
#   '0701 John Ranch': 197,
#   '166 Lisa Fords': 198,
#   '321 Camacho Causeway': 199,
#   '319 Wendy Fort Suite 179': 200,
#   '615 Clarke Spring Apt. 172': 201,
#   '554 Mcdonald Valley Apt. 539': 202,
#   '83685 Matthew Center Suite 870': 203,
#   '39218 Baker Shoals': 204,
#   '1025 Robin Square': 205,
#   '26678 Lisa Locks Apt. 904': 206,
#   '062 Poole Hollow Apt. 815': 207,
#   '194 Goodman Fall Apt. 569': 208,
#   '8580 Moore Cove': 209,
#   '954 Green Wall': 210,
#   '3304 Hernandez Run': 211,
#   '911 Sabrina Trafficway': 212,
#   '0362 Anderson Wall': 213,
#   '8614 Reed Glen': 214,
#   '6296 John Keys Suite 858': 215,
#   '82468 Michelle Village Suite 556': 216,
#   '230 Ryan Tunnel Apt. 025': 217,
#   '70147 Amanda Fields': 218,
#   '8425 Daniel Knolls Suite 288': 219,
#   '4879 Cristina Station': 220,
#   '3277 Fields Meadows Apt. 790': 221,
#   '6343 Ramirez Skyway Apt. 518': 222,
#   '977 Rita Grove Apt. 000': 223,
#   '36659 Smith Club Apt. 080': 224,
#   '9734 Beard Fields Suite 885': 225,
#   '85344 Smith Gateway Apt. 280': 226,
#   '010 Weaver Land': 227,
#   '184 Miller Manors': 228,
#   '1535 Ryan Burgs Suite 919': 229,
#   '87227 Tapia Burgs': 230,
#   '550 Cunningham Squares': 231,
#   '31701 Tucker Square Suite 893': 232,
#   '69252 Oconnor Alley Apt. 153': 233,
#   '26572 Hodge Villages Suite 512': 234,
#   '754 Smith Isle': 235,
#   '42933 Ryan Underpass': 236,
#   '4725 Hurst Curve Apt. 634': 237,
#   '172 Leonard Island': 238,
#   '2632 Stevens Light Apt. 213': 239,
#   '23843 Scott Island': 240,
#   '12087 Michael Light': 241,
#   '057 Martinez Radial': 242,
#   '5053 Bell Crescent Apt. 255': 243,
#   '1166 Castillo Mountains': 244,
#   '6602 Ortiz Pine Apt. 179': 245,
#   '343 Hannah Parkway': 246,
#   '005 Cody Estates': 247,
#   '9588 Cox Rapid Apt. 257': 248,
#   '474 Allen Haven': 249,
#   '897 Daugherty Mission': 250,
#   '8969 Fuentes Station Apt. 291': 251,
#   '26615 Nelson Lane': 252,
#   '182 Sergio Summit Apt. 129': 253,
#   '7377 Walton Extensions Apt. 979': 254,
#   '9242 Vanessa Ramp Apt. 525': 255,
#   '010 Salazar Walk': 256,
#   '8510 Acevedo Burgs': 257,
#   '507 John Overpass Suite 424': 258,
#   '4511 Choi Lock': 259,
#   '622 Robin Run Suite 764': 260,
#   '426 Mark Ports': 261,
#   '118 Justin Extension': 262,
#   '6881 King Isle Suite 228': 263,
#   '199 Patterson Fords Apt. 132': 264,
#   '78652 Scott Ports': 265,
#   '3433 Jones Branch': 266,
#   '3653 Ryan Crossroad': 267,
#   '7529 Carter Well Suite 262': 268,
#   '43235 Mckenzie Views Apt. 837': 269,
#   '354 Gutierrez Gateway': 270,
#   '17819 Jose Mount Suite 657': 271,
#   '7421 Serrano Lane Apt. 580': 272,
#   '40624 Rebecca Spurs': 273,
#   '1299 Joshua Plains': 274,
#   '3310 Davidson Spurs Apt. 107': 275,
#   '384 Newman Forks Apt. 370': 276,
#   '25748 John Wells': 277,
#   '4130 Tiffany Glen Apt. 562': 278,
#   '6114 Moran Way': 279,
#   '6911 Nicholas Keys Apt. 237': 280,
#   '6983 Carrillo Isle': 281,
#   '3047 Jeff Place': 282,
#   '6744 Jimmy Extensions': 283,
#   '974 Cindy Stream': 284,
#   '4215 Miranda Field Suite 326': 285,
#   '4503 Patricia Route': 286,
#   '725 Jo Trace Apt. 102': 287,
#   '23656 Harris Gardens Suite 698': 288,
#   '153 Mccullough Springs Apt. 857': 289,
#   '47152 Clayton Burg': 290,
#   '5036 Victoria Ports Suite 249': 291,
#   '40178 Lisa Mission': 292,
#   '3531 Hamilton Highway': 293,
#   '7921 Robert Port Suite 343': 294,
#   '2788 Brittney Island': 295,
#   '44197 Jeffrey Port Suite 050': 296,
#   '495 Fisher Throughway': 297,
#   '92021 Miranda Meadows': 298,
#   '35822 Clayton Street Apt. 679': 299,
#   '07712 Marcus Divide Apt. 831': 300,
#   '709 George Underpass Apt. 080': 301,
#   '1626 Susan Course': 302,
#   '369 Cochran Radial': 303,
#   '9297 Victor Rest Apt. 382': 304,
#   '382 Williams Stream Suite 197': 305,
#   '244 Jeffery Rapids': 306,
#   '118 Cabrera Springs Apt. 105': 307,
#   '200 Christie Mills Apt. 307': 308,
#   '386 Randolph Throughway': 309,
#   '587 Bradley Inlet Suite 281': 310,
#   '516 Brown Parks': 311,
#   '174 Jennifer Meadow Apt. 467': 312,
#   '250 Carrie Throughway': 313,
#   '76752 David Lodge Apt. 064': 314,
#   '50614 Kevin Point': 315,
#   '982 Melissa Lock': 316,
#   '24607 Charles Mountains': 317,
#   '477 Alejandro Knolls Suite 828': 318,
#   '927 Cummings Manor Suite 318': 319,
#   '09419 Lewis Rapids': 320,
#   '5097 Martin Ridges': 321,
#   '03368 Michelle Trail': 322,
#   '8617 Holmes Terrace Suite 651': 323,
#   '0654 Kevin Turnpike Apt. 084': 324,
#   '05050 Rogers Well Apt. 439': 325,
#   '062 Carl Dam': 326,
#   '78117 George Mountains': 327,
#   '68276 Matthew Springs': 328,
#   '9808 Ellis Bypass': 329,
#   '838 Amy Street Suite 107': 330,
#   '5323 Walker Island': 331,
#   '74890 Rodriguez Springs Apt. 540': 332,
#   '950 Dunn Squares': 333,
#   '13299 Patrick Terrace': 334,
#   '77921 Costa Villages': 335,
#   '5364 William Harbor': 336,
#   '508 Erin Mount': 337,
#   '75533 Tamara Valleys': 338,
#   '0537 Margaret Common Suite 526': 339,
#   '7535 Amanda Manors Suite 293': 340,
#   '95835 Garcia Rue': 341,
#   '329 Emily Cape': 342,
#   '6385 Donald Square Suite 429': 343,
#   '94975 David Mews Apt. 316': 344,
#   '50932 Neal Valley': 345,
#   '75703 Hernandez Corner Suite 348': 346,
#   '980 Smith Gardens': 347,
#   '6033 Young Track Suite 804': 348,
#   '8829 Steele Station': 349,
#   '6251 Payne Flats Apt. 581': 350,
#   '7314 Johnson Square Apt. 296': 351,
#   '696 Matthew Ford Suite 157': 352,
#   '1683 Davidson Freeway': 353,
#   '3283 James Station': 354,
#   '330 Montoya Ramp': 355,
#   '63542 Luna Brook Apt. 012': 356,
#   '28925 Powell Mountains Apt. 762': 357,
#   '2838 White Fields Apt. 473': 358,
#   '1833 Jeanette Stravenue': 359,
#   '5901 Foster Pine': 360,
#   '886 Nicole Key': 361,
#   '27909 Peter Motorway': 362,
#   '82201 Bradley Radial Suite 703': 363,
#   '05561 Farrell Crescent': 364,
#   '9824 Mitchell Run': 365,
#   '588 Smith Lights Suite 786': 366,
#   '70858 Jasmine Meadows Apt. 135': 367,
#   '5395 Colon Burgs Suite 037': 368,
#   '43809 Kenneth Circles Suite 152': 369,
#   '543 Ware Path Apt. 593': 370,
#   '54220 April Union Suite 403': 371,
#   '79472 Stevens Trace Apt. 120': 372,
#   '949 Smith Parkway': 373,
#   '822 Austin Spur': 374,
#   '67632 Martin Gateway': 375,
#   '72966 Shannon Pass Apt. 391': 376,
#   '611 Michael Rue': 377,
#   '957 Miller Falls': 378,
#   '411 Laurie Fords': 379,
#   '07177 William Dale Apt. 547': 380,
#   '875 Amy Point': 381,
#   '9870 Collins Flat': 382,
#   '428 Morgan River': 383,
#   '4529 Cannon Alley': 384,
#   '8619 Lisa Manors Apt. 871': 385,
#   '1561 Chase Grove': 386,
#   '31954 Eugene Lane Suite 572': 387,
#   '785 Kevin Walk Suite 237': 388,
#   '0665 Lisa Alley': 389,
#   '3595 Susan Island Suite 063': 390,
#   '7915 Dawn Roads Apt. 544': 391,
#   '597 Jenny Ford Apt. 543': 392,
#   '736 Moss Motorway Suite 549': 393,
#   '79414 Clark Lakes Suite 966': 394,
#   '195 Murray Overpass Apt. 384': 395,
#   '08056 Alvarado Club Suite 699': 396,
#   '7898 Wanda Springs': 397,
#   '84033 Pitts Overpass': 398,
#   '73869 Connie Prairie': 399,
#   '083 Karen Island Apt. 656': 400,
#   '376 Brown Courts': 401,
#   '79816 Jackson Squares': 402,
#   '594 Berry Lights Apt. 392': 403,
#   '13108 Jennifer Passage': 404,
#   '431 Tracy Expressway': 405,
#   '1323 Derek Mission': 406,
#   '4319 Watson Shoals Suite 658': 407,
#   '933 Martin Rapids': 408,
#   '9331 Robert Passage Suite 327': 409,
#   '62934 Maria Cliffs Suite 350': 410,
#   '3426 David Divide Suite 717': 411,
#   '17667 Price Spur Apt. 366': 412,
#   '8851 Reese Neck': 413,
#   '292 Cassidy Oval': 414,
#   '995 Benjamin Bypass': 415,
#   '00315 Ashley Valleys': 416,
#   '574 Patricia Extensions': 417,
#   '02018 Gary Key Apt. 911': 418,
#   '9727 Deleon Mountain': 419,
#   '0189 Emily Prairie': 420,
#   '06393 Nancy Parkways Suite 855': 421,
#   '589 Matthew Brooks': 422,
#   '69085 Short Shores': 423,
#   '39227 Mcpherson Shoals': 424,
#   '9572 Austin Forge Suite 612': 425,
#   '670 Le Meadows Suite 250': 426,
#   '2924 Bobby Trafficway': 427,
#   '610 Samantha Park Suite 149': 428,
#   '6682 Green Forks': 429,
#   '529 West Key': 430,
#   '08966 Beltran Route Suite 905': 431,
#   '72743 Brian Run': 432,
#   '463 Willie Estates': 433,
#   '7188 Melissa Crest Apt. 151': 434,
#   '2851 Foster Shoals': 435,
#   '304 Ryan Port Suite 335': 436,
#   '46297 Benjamin Plains Suite 703': 437,
#   '3256 Brooks Field': 438,
#   '126 Underwood Drive': 439,
#   '663 Anna Plaza': 440,
#   '87665 Karen Mill Apt. 586': 441,
#   '7290 Ashlee Keys': 442,
#   '04975 Allison Shoal': 443,
#   '8465 Reed Green Suite 559': 444,
#   '767 Adam Mill Apt. 115': 445,
#   '840 Werner Lock Apt. 852': 446,
#   '8840 Miller Port Suite 645': 447,
#   '220 Frank Gardens': 448,
#   '707 Anthony Causeway': 449,
#   '85430 Julie Trafficway Suite 792': 450,
#   '2870 Bean Terrace Apt. 756': 451,
#   '901 Todd Gardens Apt. 466': 452,
#   '8088 Sherman Radial Suite 689': 453,
#   '152 James Centers Apt. 768': 454,
#   '77663 Colleen Freeway': 455,
#   '5783 Evan Roads Apt. 465': 456,
#   '4739 Martin Common': 457,
#   '7402 West Ranch': 458,
#   '4938 Hatfield Course': 459,
#   '23142 Montoya Island Apt. 742': 460,
#   '0423 Kirby Field Suite 623': 461,
#   '555 Michael Burgs': 462,
#   '44951 Williams Brooks': 463,
#   '428 Michael Tunnel Apt. 377': 464,
#   '222 Freeman Islands': 465,
#   '23220 Eaton Harbors': 466,
#   '57256 Raymond Ports': 467,
#   '701 Wilson Divide': 468,
#   '22502 Baker Mount Suite 241': 469,
#   '826 Benjamin Stravenue': 470,
#   '502 Rice Plaza Apt. 979': 471,
#   '46809 Toni Flat Suite 216': 472,
#   '3325 Gregory Square': 473,
#   '25961 Beverly Union Apt. 042': 474,
#   '4138 David Fall': 475,
#   '3326 Hannah Fords': 476,
#   '7309 Sophia Causeway Suite 702': 477,
#   '234 Bridges Wells Apt. 389': 478,
#   '162 Jessica Row Apt. 072': 479,
#   '923 Jordan Road': 480,
#   '6366 French Field': 481,
#   '26544 Andrea Glen': 482,
#   '77872 Andrea Glen Apt. 543': 483,
#   '50843 Vincent Mission': 484,
#   '172 Paula Inlet Apt. 650': 485,
#   '572 Davis Mountains': 486,
#   '865 Thomas Village': 487,
#   '5796 Lee Coves Apt. 286': 488,
#   '4936 Michelle Points': 489,
#   '93914 Gregory Via': 490,
#   '31281 Thomas Inlet': 491,
#   '06539 Gregory Mountains Suite 029': 492,
#   '19838 Tonya Prairie Apt. 947': 493,
#   '16285 Jessica Lights': 494,
#   '071 Wise Trace': 495,
#   '44089 Carrie Crossing Suite 954': 496,
#   '7118 Jessica Unions Apt. 789': 497,
#   '81261 Garcia Underpass Suite 741': 498,
#   '371 Anthony Trail Suite 354': 499,
#   '098 Stewart Hill': 500,
#   '9412 Harris Mews': 501,
#   '298 Kayla Lights': 502,
#   '138 Stephen Ridges Apt. 978': 503,
#   '7178 Willis Drive': 504,
#   '65417 Walsh Radial Suite 691': 505,
#   '6760 Donovan Lakes': 506,
#   '7107 Henderson Station': 507,
#   '27203 Darrell Landing': 508,
#   '5758 Yates Center': 509,
#   '6139 Mark Rapid Apt. 651': 510,
#   '13956 Hughes Causeway Suite 124': 511,
#   '75952 Wilson Course': 512,
#   '86882 Desiree Camp Suite 047': 513,
#   '065 Jones Stravenue': 514,
#   '3136 Silva Stream': 515,
#   '04139 Johnson Prairie Suite 401': 516,
#   '9579 Porter Tunnel': 517,
#   '79209 Gary Dale': 518,
#   '5619 Mendoza Inlet': 519,
#   '3423 Michael Canyon Suite 276': 520,
#   '285 George Lake': 521,
#   '8152 Brittany Centers': 522,
#   '24318 Dixon Mills': 523,
#   '95793 Andrea Ville Suite 533': 524,
#   '892 Solis Neck': 525,
#   '2161 Blankenship Freeway': 526,
#   '1911 Fisher Brook': 527,
#   '97689 Davis Point Apt. 967': 528,
#   '0925 Lang Extensions': 529,
#   '748 Bryan Fields Suite 935': 530,
#   '27479 Reeves Dale': 531,
#   '0371 Aimee Neck Suite 856': 532,
#   '6157 Nichols Mews': 533,
#   '4470 Jillian Courts': 534,
#   '169 Shelia Knoll Suite 753': 535,
#   '574 David Locks Suite 207': 536,
#   '109 Brian Lights Apt. 504': 537,
#   '97405 Vazquez Plains': 538,
#   '17666 David Valleys': 539,
#   '1441 Bradley Place': 540,
#   '425 Caleb Point Apt. 050': 541,
#   '18316 Cannon Place': 542,
#   '0157 Samuel Mission Suite 379': 543,
#   '651 Miller Common': 544,
#   '4483 Sharp Ferry Apt. 468': 545,
#   '5517 Stacy Land': 546,
#   '4456 Dunn Roads': 547,
#   '02110 Lucas Freeway Suite 517': 548,
#   '3206 Hall Divide Suite 282': 549,
#   '558 Michael Estates': 550,
#   '58188 Madison Meadow Apt. 949': 551,
#   '861 Karen Common': 552,
#   '1984 Taylor Island Suite 836': 553,
#   '9486 Joel Common Suite 554': 554,
#   '4349 Anna Flat Suite 214': 555,
#   '07943 Davis River': 556,
#   '154 Hernandez Keys': 557,
#   '8030 Beck Motorway': 558,
#   '825 Martinez Springs Apt. 625': 559,
#   '3270 Scott Islands': 560,
#   '8172 Robertson Parkways Suite 072': 561,
#   '2989 Murray Inlet': 562,
#   '1943 Dennis Inlet Suite 145': 563,
#   '9886 Anita Drive': 564,
#   '916 Charles Road': 565,
#   '27718 Mason Bypass': 566,
#   '622 Bradley Knoll Apt. 758': 567,
#   '06808 Ryan Valleys': 568,
#   '542 Steve Curve Suite 011': 569,
#   '6313 Scott Trace': 570,
#   '7600 Stephen Course Suite 031': 571,
#   '619 Jeremy Garden Apt. 681': 572,
#   '47144 Roberts Keys': 573,
#   '98897 Bennett Lodge': 574,
#   '295 Page Creek Suite 181': 575,
#   '9853 Flynn Hollow Apt. 602': 576,
#   '941 Adam Stravenue': 577,
#   '15315 Vaughn Park Suite 356': 578,
#   '9345 Spencer Junctions Suite 183': 579,
#   '4257 Perez Mall': 580,
#   '1980 Vasquez Manors Apt. 574': 581,
#   '6274 David Oval Suite 725': 582,
#   '835 Reese Views Suite 884': 583,
#   '393 Carroll Route Suite 197': 584,
#   '01892 Patricia Vista Apt. 828': 585,
#   '28223 Ward Summit Apt. 664': 586,
#   '400 Zuniga Pine': 587,
#   '7952 Karen Pike': 588,
#   '30587 Fox Shores Apt. 627': 589,
#   '42965 Christopher Fords Suite 659': 590,
#   '08580 Jeremy Falls': 591,
#   '372 Jeffrey Course': 592,
#   '03030 White Lakes': 593,
#   '334 Adam Mountains Apt. 868': 594,
#   '852 Thomas Well Suite 339': 595,
#   '954 Reyes Ways': 596,
#   '3638 Marsh Union': 597,
#   '32941 Krystal Mill Apt. 552': 598,
#   '3872 Matthew Skyway': 599,
#   '383 Contreras Hills Suite 658': 600,
#   '79019 Taylor Cliffs': 601,
#   '0005 Morrison Land': 602,
#   '133 Alyssa Plains': 603,
#   '561 Little Plain Apt. 738': 604,
#   '715 Courtney Pike Suite 932': 605,
#   '477 Wheeler Burg': 606,
#   '180 Graves Shore': 607,
#   '3683 Parrish Circles': 608,
#   '25036 Contreras Turnpike Suite 270': 609,
#   '148 Baker Field': 610,
#   '444 Robert Mews': 611,
#   '524 Wu Spurs Suite 894': 612,
#   '296 Maria Street': 613,
#   '25713 Hamilton Grove Apt. 903': 614,
#   '376 John Fork Suite 848': 615,
#   '673 Delgado Burg': 616,
#   '6278 Stephanie Unions': 617,
#   '33165 Larry Walks Suite 960': 618,
#   '312 Eric Expressway Apt. 014': 619,
#   '5569 Phillips Neck Apt. 003': 620,
#   '72030 Shelton Crossing Apt. 742': 621,
#   '000 Jennifer Mills': 622,
#   '053 Kim Valley Suite 928': 623,
#   '63502 Brown Road Apt. 318': 624,
#   '32301 Albert River Suite 364': 625,
#   '135 Joseph Mountains': 626,
#   '8030 Walker Heights': 627,
#   '94225 Smith Springs Apt. 617': 628,
#   '93970 Trujillo Causeway': 629,
#   '63991 Destiny Rue Apt. 651': 630,
#   '36366 Smith Road': 631,
#   '90662 Lewis Avenue': 632,
#   '169 Edward Inlet': 633,
#   '872 Justin Views Suite 746': 634,
#   '1339 Johnson Landing Suite 007': 635,
#   '55363 Aaron Circle Suite 450': 636,
#   '121 Solis Summit Apt. 934': 637,
#   '464 Newman Crossroad': 638,
#   '979 Stewart Lake': 639,
#   '401 Escobar Port': 640,
#   '3522 Park Wells Suite 528': 641,
#   '70761 Fitzpatrick Brooks Suite 631': 642,
#   '82073 Jessica Camp': 643,
#   '8850 Jessica Center': 644,
#   '0912 Mark Fields Apt. 080': 645,
#   '2306 Clark Ranch Suite 515': 646,
#   '56812 Francis Courts': 647,
#   '086 Pierce Cove': 648,
#   '7055 Fernandez Estates Apt. 676': 649,
#   '433 Blake Roads Suite 967': 650,
#   '0638 Fred Ramp Suite 086': 651,
#   '755 Solis Isle Suite 075': 652,
#   '144 Evans Islands Apt. 683': 653,
#   '776 Martin Ridge': 654,
#   '290 Kathryn Fall': 655,
#   '7337 Browning Falls Suite 027': 656,
#   '6993 Carr Lodge Apt. 311': 657,
#   '830 Myers Plaza Apt. 384': 658,
#   '193 Catherine Ways': 659,
#   '5572 Kelly Plains Apt. 952': 660,
#   '37732 Joe Courts Apt. 752': 661,
#   '537 Rice Square Suite 040': 662,
#   '25360 Mcgee Forge': 663,
#   '1049 John Ports Suite 057': 664,
#   '94431 Matthew Mall Suite 296': 665,
#   '351 Darlene Green': 666,
#   '5155 Mary Common Apt. 927': 667,
#   '672 Randall Burg Suite 551': 668,
#   '082 Hernandez Bypass Apt. 886': 669,
#   '128 Nathan Ramp': 670,
#   '1852 Vincent Isle Suite 328': 671,
#   '383 Long Islands': 672,
#   '0107 Clements Point': 673,
#   '653 Jessica Extension Apt. 668': 674,
#   '582 Rodriguez Wells': 675,
#   '084 Holmes Avenue Suite 206': 676,
#   '6778 Campos Field': 677,
#   '8699 Lindsay Ford Apt. 486': 678,
#   '034 Kimberly Mountains': 679,
#   '03090 Fisher Forges Apt. 200': 680,
#   '246 Stewart Green Suite 149': 681,
#   '01505 Amy Stravenue': 682,
#   '55505 Christy Via': 683,
#   '71309 Martinez Stravenue': 684,
#   '83690 Nicholas Ports Apt. 846': 685,
#   '2193 Osborne Run Apt. 789': 686,
#   '1125 Ray Track': 687,
#   '58665 Nicholas Ford Suite 348': 688,
#   '868 Brady Mill Apt. 837': 689,
#   '97070 Anderson Land': 690,
#   '838 Franklin Prairie Apt. 902': 691,
#   '2807 Parker Station Suite 080': 692,
#   '9670 Monroe Junctions': 693,
#   '4900 Curtis Gardens Suite 952': 694,
#   '20938 Barbara Viaduct': 695,
#   '789 Herring Manors': 696,
#   '094 Owens Underpass': 697,
#   '952 Joseph Throughway': 698,
#   '797 Jennifer Loop Suite 634': 699,
#   '659 Nicole Cove Suite 560': 700,
#   '478 George Course Apt. 056': 701,
#   '54822 Hill Forks': 702,
#   '9471 Wong Islands': 703,
#   '23383 Denise Pine Apt. 099': 704,
#   '3603 Mitchell Court': 705,
#   '3786 Hale Corners': 706,
#   '91542 Marissa Shores Apt. 053': 707,
#   '956 Paul Fields Suite 108': 708,
#   '490 Baldwin Alley Apt. 468': 709,
#   '28777 Stewart Plains Apt. 495': 710,
#   '815 Heather Divide Apt. 965': 711,
#   '91644 Crystal Drives': 712,
#   '117 Natasha Vista Suite 936': 713,
#   '7538 Carrie Meadow Suite 574': 714,
#   '350 Stacy Glens': 715,
#   '5452 Patricia Inlet Apt. 280': 716,
#   '976 Hubbard Lodge': 717,
#   '6807 Jacob Skyway Apt. 331': 718,
#   '622 Williams Trafficway': 719,
#   '560 Molina Path': 720,
#   '7644 Joseph Fields': 721,
#   '669 Moore Shoal': 722,
#   '836 Stephanie Union': 723,
#   '14017 Thomas Plaza': 724,
#   '25454 Leonard Lake': 725,
#   '3867 Susan Corners Apt. 883': 726,
# ...
#   38915: 955,
#   93427: 956,
#   67346: 957,
#   33762: 958,
#   61364: 959,
#   35896: 960,
#   37887: 961,
#   48054: 962,
#   53045: 963,
#   94508: 964,
#   18446: 965,
#   78644: 966,
#   39562: 967,
#   21657: 968,
#   4032: 969,
#   14141: 970,
#   56367: 971,
#   28530: 972,
#   22204: 973,
#   35211: 974,
#   40502: 975,
#   13795: 976,
#   87417: 977,
#   66958: 978,
#   65745: 979,
#   98118: 980,
#   52658: 981,
#   73044: 982,
#   99921: 983,
#   38668: 984},
#  'job': {'Psychologist, counselling': 0,
#   'Special educational needs teacher': 1,
#   'Nature conservation officer': 2,
#   'Patent attorney': 3,
#   'Dance movement psychotherapist': 4,
#   'Transport planner': 5,
#   'Arboriculturist': 6,
#   'Designer, multimedia': 7,
#   'Public affairs consultant': 8,
#   'Pathologist': 9,
#   'IT trainer': 10,
#   'Systems developer': 11,
#   'Engineer, land': 12,
#   'Systems analyst': 13,
#   'Naval architect': 14,
#   'Radiographer, diagnostic': 15,
#   'Programme researcher, broadcasting/film/video': 16,
#   'Energy engineer': 17,
#   'Event organiser': 18,
#   'Operational researcher': 19,
#   'Market researcher': 20,
#   'Probation officer': 21,
#   'Leisure centre manager': 22,
#   'Corporate investment banker': 23,
#   'Therapist, occupational': 24,
#   'Call centre manager': 25,
#   'Police officer': 26,
#   'Education officer, museum': 27,
#   'Physiotherapist': 28,
#   'Network engineer': 29,
#   'Forensic psychologist': 30,
#   'Geochemist': 31,
#   'Armed forces training and education officer': 32,
#   'Designer, furniture': 33,
#   'Optician, dispensing': 34,
#   'Psychologist, forensic': 35,
#   'Librarian, public': 36,
#   'Fine artist': 37,
#   'Scientist, research (maths)': 38,
#   'Research officer, trade union': 39,
#   'Tourism officer': 40,
#   'Human resources officer': 41,
#   'Surveyor, minerals': 42,
#   'Applications developer': 43,
#   'Video editor': 44,
#   'Curator': 45,
#   'Research officer, political party': 46,
#   'Engineer, mining': 47,
#   'Education officer, community': 48,
#   'Physicist, medical': 49,
#   'Amenity horticulturist': 50,
#   'Electrical engineer': 51,
#   'Television camera operator': 52,
#   'Higher education careers adviser': 53,
#   'Ambulance person': 54,
#   'Dealer': 55,
#   'Paediatric nurse': 56,
#   'Trading standards officer': 57,
#   'Engineer, technical sales': 58,
#   'Designer, jewellery': 59,
#   'Clinical biochemist': 60,
#   'Engineer, electronics': 61,
#   'Water engineer': 62,
#   'Science writer': 63,
#   'Film/video editor': 64,
#   'Solicitor, Scotland': 65,
#   'Product/process development scientist': 66,
#   'Tree surgeon': 67,
#   'Careers information officer': 68,
#   'Geologist, engineering': 69,
#   'Counsellor': 70,
#   'Freight forwarder': 71,
#   'Senior tax professional/tax inspector': 72,
#   'Engineer, broadcasting (operations)': 73,
#   'English as a second language teacher': 74,
#   'Economist': 75,
#   'Child psychotherapist': 76,
#   'Claims inspector/assessor': 77,
#   'Tourist information centre manager': 78,
#   'Exhibitions officer, museum/gallery': 79,
#   'Location manager': 80,
#   'Engineer, biomedical': 81,
#   'Research scientist (physical sciences)': 82,
#   'Purchasing manager': 83,
#   'Editor, magazine features': 84,
#   'Operations geologist': 85,
#   'Interpreter': 86,
#   'Engineering geologist': 87,
#   'Agricultural consultant': 88,
#   'Paramedic': 89,
#   'Financial adviser': 90,
#   'Administrator, education': 91,
#   'Educational psychologist': 92,
#   'Financial trader': 93,
#   'Audiological scientist': 94,
#   'Scientist, audiological': 95,
#   'Administrator, charities/voluntary organisations': 96,
#   'Health service manager': 97,
#   'Retail merchandiser': 98,
#   'Telecommunications researcher': 99,
#   'Exercise physiologist': 100,
#   'Accounting technician': 101,
#   'Product designer': 102,
#   'Waste management officer': 103,
#   'Mining engineer': 104,
#   'Surgeon': 105,
#   'Therapist, horticultural': 106,
#   'Environmental consultant': 107,
#   'Broadcast presenter': 108,
#   'Producer, radio': 109,
#   'Engineer, communications': 110,
#   'Historic buildings inspector/conservation officer': 111,
#   'Teacher, English as a foreign language': 112,
#   'Materials engineer': 113,
#   'Health visitor': 114,
#   'Medical secretary': 115,
#   'Theatre director': 116,
#   'Technical brewer': 117,
#   'Land/geomatics surveyor': 118,
#   'Engineer, structural': 119,
#   'Diagnostic radiographer': 120,
#   'Television production assistant': 121,
#   'Medical sales representative': 122,
#   'Building control surveyor': 123,
#   'Therapist, sports': 124,
#   'Structural engineer': 125,
#   'Commercial/residential surveyor': 126,
#   'Database administrator': 127,
#   'Exhibition designer': 128,
#   'Training and development officer': 129,
#   'Mechanical engineer': 130,
#   'Medical physicist': 131,
#   'Administrator': 132,
#   'Mudlogger': 133,
#   'Fisheries officer': 134,
#   'Conservator, museum/gallery': 135,
#   'Programmer, multimedia': 136,
#   'Cytogeneticist': 137,
#   'Multimedia programmer': 138,
#   'Counselling psychologist': 139,
#   'Chiropodist': 140,
#   'Teacher, early years/pre': 141,
#   'Cartographer': 142,
#   'Pensions consultant': 143,
#   'Primary school teacher': 144,
#   'Electronics engineer': 145,
#   'Museum/gallery exhibitions officer': 146,
#   'Air broker': 147,
#   'Chemical engineer': 148,
#   'Advertising account executive': 149,
#   'Advertising account planner': 150,
#   'Chartered legal executive (England and Wales)': 151,
#   'Psychiatric nurse': 152,
#   'Secondary school teacher': 153,
#   'Librarian, academic': 154,
#   'Embryologist, clinical': 155,
#   'Immunologist': 156,
#   'Television floor manager': 157,
#   'Contractor': 158,
#   'Health physicist': 159,
#   'Copy': 160,
#   'Bookseller': 161,
#   'Land': 162,
#   'Chartered loss adjuster': 163,
#   'Occupational psychologist': 164,
#   'Facilities manager': 165,
#   'Further education lecturer': 166,
#   'Archivist': 167,
#   'Investment analyst': 168,
#   'Engineer, building services': 169,
#   'Psychologist, sport and exercise': 170,
#   'Journalist, newspaper': 171,
#   'Doctor, hospital': 172,
#   'Phytotherapist': 173,
#   'Pharmacologist': 174,
#   'Horticultural therapist': 175,
#   'Hydrologist': 176,
#   'Community arts worker': 177,
#   'Public house manager': 178,
#   'Architect': 179,
#   'Lexicographer': 180,
#   'Psychotherapist, child': 181,
#   'Teacher, secondary school': 182,
#   'Toxicologist': 183,
#   'Commercial horticulturist': 184,
#   'Podiatrist': 185,
#   'Building surveyor': 186,
#   'Architectural technologist': 187,
#   'Editor, film/video': 188,
#   'Social researcher': 189,
#   'Wellsite geologist': 190,
#   'Minerals surveyor': 191,
#   'Designer, ceramics/pottery': 192,
#   'Mental health nurse': 193,
#   'Volunteer coordinator': 194,
#   'Chief Technology Officer': 195,
#   'Camera operator': 196,
#   'Copywriter, advertising': 197,
#   'Surveyor, mining': 198,
#   'Product manager': 199,
#   "Nurse, children's": 200,
#   'Pension scheme manager': 201,
#   'Archaeologist': 202,
#   'Sub': 203,
#   'Designer, interior/spatial': 204,
#   'Futures trader': 205,
#   'Chief Financial Officer': 206,
#   'Museum education officer': 207,
#   'Quantity surveyor': 208,
#   'Physiological scientist': 209,
#   'Loss adjuster, chartered': 210,
#   'Pilot, airline': 211,
#   'Production assistant, radio': 212,
#   'Immigration officer': 213,
#   'Retail banker': 214,
#   'Health and safety adviser': 215,
#   'Teacher, special educational needs': 216,
#   'Jewellery designer': 217,
#   'Community pharmacist': 218,
#   'Control and instrumentation engineer': 219,
#   'Make': 220,
#   'Early years teacher': 221,
#   'Sales professional, IT': 222,
#   'Scientist, marine': 223,
#   'Intelligence analyst': 224,
#   'Clinical research associate': 225,
#   'Administrator, local government': 226,
#   'Barrister': 227,
#   'Engineer, control and instrumentation': 228,
#   'Clothing/textile technologist': 229,
#   'Development worker, community': 230,
#   'Art therapist': 231,
#   'Sales executive': 232,
#   'Armed forces logistics/support/administrative officer': 233,
#   'Optometrist': 234,
#   'Insurance underwriter': 235,
#   'Charity officer': 236,
#   'Civil Service fast streamer': 237,
#   'Retail buyer': 238,
#   'Magazine features editor': 239,
#   'Equities trader': 240,
#   'Trade mark attorney': 241,
#   'Research scientist (life sciences)': 242,
#   'Psychotherapist': 243,
#   'Pharmacist, community': 244,
#   'Risk analyst': 245,
#   'Engineer, maintenance': 246,
#   'Logistics and distribution manager': 247,
#   'Water quality scientist': 248,
#   'Lecturer, further education': 249,
#   'Production assistant, television': 250,
#   'Tour manager': 251,
#   'Music therapist': 252,
#   'Surveyor, land/geomatics': 253,
#   'Engineer, production': 254,
#   'Acupuncturist': 255,
#   'Hospital doctor': 256,
#   'Teacher, primary school': 257,
#   'Accountant, chartered public finance': 258,
#   'Illustrator': 259,
#   'Scientist, physiological': 260,
#   'Buyer, industrial': 261,
#   'Scientist, research (physical sciences)': 262,
#   'Radio producer': 263,
#   'Manufacturing engineer': 264,
#   'Animal technologist': 265,
#   'Production engineer': 266,
#   'Biochemist, clinical': 267,
#   'Engineer, manufacturing': 268,
#   'Comptroller': 269,
#   'General practice doctor': 270,
#   'Designer, industrial/product': 271,
#   'Prison officer': 272,
#   'Merchandiser, retail': 273,
#   'Engineer, drilling': 274,
#   'Engineer, petroleum': 275,
#   'Cabin crew': 276,
#   'Commissioning editor': 277,
#   'Accountant, chartered certified': 278,
#   'Local government officer': 279,
#   'Professor Emeritus': 280,
#   'Press sub': 281,
#   'Chartered public finance accountant': 282,
#   'Writer': 283,
#   'Chief Executive Officer': 284,
#   'Occupational hygienist': 285,
#   'Doctor, general practice': 286,
#   'Community education officer': 287,
#   'Landscape architect': 288,
#   'Occupational therapist': 289,
#   'Special effects artist': 290,
#   'Civil engineer, contracting': 291,
#   "Barrister's clerk": 292,
#   'Travel agency manager': 293,
#   'Associate Professor': 294,
#   'Neurosurgeon': 295,
#   'Plant breeder/geneticist': 296,
#   'Radio broadcast assistant': 297,
#   'Field seismologist': 298,
#   'Industrial/product designer': 299,
#   'Metallurgist': 300,
#   "Politician's assistant": 301,
#   'Insurance claims handler': 302,
#   'Theme park manager': 303,
#   'Gaffer': 304,
#   'Chief Strategy Officer': 305,
#   'Heritage manager': 306,
#   'Ceramics designer': 307,
#   'Animator': 308,
#   'Oceanographer': 309,
#   'Colour technologist': 310,
#   'Engineer, agricultural': 311,
#   'Therapist, drama': 312,
#   'Orthoptist': 313,
#   'Learning mentor': 314,
#   'Arts development officer': 315,
#   'Biomedical engineer': 316,
#   'Race relations officer': 317,
#   'Therapist, music': 318,
#   'Retail manager': 319,
#   'Furniture designer': 320,
#   'Building services engineer': 321,
#   'Maintenance engineer': 322,
#   'Aid worker': 323,
#   'Editor, commissioning': 324,
#   'Private music teacher': 325,
#   'Scientist, biomedical': 326,
#   'Public relations account executive': 327,
#   'Dispensing optician': 328,
#   'Advice worker': 329,
#   'Hydrographic surveyor': 330,
#   'Geoscientist': 331,
#   'Environmental health practitioner': 332,
#   'Learning disability nurse': 333,
#   'Chief Operating Officer': 334,
#   'Scientific laboratory technician': 335,
#   'Records manager': 336,
#   'Barista': 337,
#   'Marketing executive': 338,
#   'Tax inspector': 339,
#   'Musician': 340,
#   'Therapist, art': 341,
#   'Engineer, automotive': 342,
#   'Clinical psychologist': 343,
#   'Warden/ranger': 344,
#   'Surveyor, rural practice': 345,
#   'Sport and exercise psychologist': 346,
#   'Education administrator': 347,
#   'Chief of Staff': 348,
#   'Nurse, mental health': 349,
#   'Music tutor': 350,
#   'Planning and development surveyor': 351,
#   'Teaching laboratory technician': 352,
#   'Chief Marketing Officer': 353,
#   'Theatre manager': 354,
#   'Quarry manager': 355,
#   'Interior and spatial designer': 356,
#   'Lecturer, higher education': 357,
#   'Regulatory affairs officer': 358,
#   'Secretary/administrator': 359,
#   'Chemist, analytical': 360,
#   'Designer, exhibition/display': 361,
#   'Pharmacist, hospital': 362,
#   'Site engineer': 363,
#   'Equality and diversity officer': 364,
#   'Public librarian': 365,
#   'Town planner': 366,
#   'Chartered accountant': 367,
#   'Programmer, applications': 368,
#   'Manufacturing systems engineer': 369,
#   'Web designer': 370,
#   'Community development worker': 371,
#   'Animal nutritionist': 372,
#   'Petroleum engineer': 373,
#   'Information systems manager': 374,
#   'Press photographer': 375,
#   'Insurance risk surveyor': 376,
#   'Soil scientist': 377,
#   'Buyer, retail': 378,
#   'Public relations officer': 379,
#   'Health promotion specialist': 380,
#   'Psychiatrist': 381,
#   'Visual merchandiser': 382,
#   'Rural practice surveyor': 383,
#   'Hotel manager': 384,
#   'Communications engineer': 385,
#   'Insurance broker': 386,
#   'Radiographer, therapeutic': 387,
#   'Set designer': 388,
#   'Tax adviser': 389,
#   'Drilling engineer': 390,
#   'Fitness centre manager': 391,
#   'Farm manager': 392,
#   'Management consultant': 393,
#   'Energy manager': 394,
#   'Museum/gallery conservator': 395,
#   'Herbalist': 396,
#   'Osteopath': 397,
#   'Statistician': 398,
#   'Hospital pharmacist': 399,
#   'Estate manager/land agent': 400,
#   'Sports development officer': 401,
#   'Investment banker, corporate': 402,
#   'Biomedical scientist': 403,
#   'Television/film/video producer': 404,
#   'Nutritional therapist': 405,
#   'Company secretary': 406,
#   'Production manager': 407,
#   'Magazine journalist': 408,
#   'Media buyer': 409,
#   'Data scientist': 410,
#   'Engineer, civil (contracting)': 411,
#   'Herpetologist': 412,
#   'Garment/textile technologist': 413,
#   'Scientist, research (medical)': 414,
#   'Civil Service administrator': 415,
#   'Airline pilot': 416,
#   'Textile designer': 417,
#   'Environmental manager': 418,
#   'Furniture conservator/restorer': 419,
#   'Horticultural consultant': 420,
#   'Firefighter': 421,
#   'Geophysicist/field seismologist': 422,
#   'Psychologist, clinical': 423,
#   'Development worker, international aid': 424,
#   'Sports administrator': 425,
#   'IT consultant': 426,
#   'Presenter, broadcasting': 427,
#   'Outdoor activities/education manager': 428,
#   'Field trials officer': 429,
#   'Social research officer, government': 430,
#   'English as a foreign language teacher': 431,
#   'Restaurant manager, fast food': 432,
#   'Hydrogeologist': 433,
#   'Research scientist (medical)': 434,
#   'Designer, television/film set': 435,
#   'Geneticist, molecular': 436,
#   'Designer, textile': 437,
#   'Licensed conveyancer': 438,
#   'Emergency planning/management officer': 439,
#   'Geologist, wellsite': 440,
#   'Air cabin crew': 441,
#   'Seismic interpreter': 442,
#   'Surveyor, hydrographic': 443,
#   'Charity fundraiser': 444,
#   'Stage manager': 445,
#   'Aeronautical engineer': 446,
#   'Glass blower/designer': 447,
#   'Ecologist': 448,
#   'Horticulturist, commercial': 449,
#   'Research scientist (maths)': 450,
#   'Engineer, aeronautical': 451,
#   'Conservation officer, historic buildings': 452,
#   'Art gallery manager': 453,
#   'Advertising copywriter': 454,
#   'Engineer, civil (consulting)': 455,
#   'Oncologist': 456,
#   'Engineer, materials': 457,
#   'Scientist, clinical (histocompatibility and immunogenetics)': 458,
#   'Investment banker, operational': 459,
#   'Medical technical officer': 460,
#   'Academic librarian': 461,
#   'Artist': 462,
#   'Clinical cytogeneticist': 463,
#   'TEFL teacher': 464,
#   'Administrator, arts': 465,
#   'Teacher, adult education': 466,
#   'Catering manager': 467,
#   'Environmental education officer': 468,
#   'Conservator, furniture': 469,
#   'Analytical chemist': 470,
#   'Broadcast engineer': 471,
#   'Media planner': 472,
#   'Lawyer': 473,
#   'Producer, television/film/video': 474,
#   'Armed forces technical officer': 475,
#   'Engineer, site': 476,
#   'Contracting civil engineer': 477,
#   'Veterinary surgeon': 478,
#   'Sales promotion account executive': 479,
#   'Broadcast journalist': 480,
#   'Dancer': 481,
#   'Forest/woodland manager': 482,
#   'Personnel officer': 483,
#   'Industrial buyer': 484,
#   'Accountant, chartered': 485,
#   'Air traffic controller': 486,
#   'Careers adviser': 487,
#   'Information officer': 488,
#   'Ship broker': 489,
#   'Legal secretary': 490,
#   'Homeopath': 491,
#   'Solicitor': 492,
#   'Warehouse manager': 493,
#   'Engineer, water': 494,
#   'Operational investment banker': 495,
#   'Software engineer': 496}}

# %%
#############################################
# Step 2: Create a Custom Dataset for Fraud Samples
#############################################
class SparkovFraudDataset(Dataset):
    def __init__(self, num_data, cat_data):
        # Convert numeric data to float tensor
        self.num_data = torch.tensor(num_data, dtype=torch.float32)
        # Keep categorical data as long tensor (integer codes)
        self.cat_data = torch.tensor(cat_data, dtype=torch.long)
        
    def __len__(self):
        return self.num_data.shape[0]
    
    def __getitem__(self, idx):
        return self.num_data[idx], self.cat_data[idx]

# Create dataset for fraud samples
fraud_dataset = SparkovFraudDataset(X_train_num, X_train_cat)

# %%
#############################################
# Step 3: Set Device
#############################################
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %%
#############################################
# Step 4: Diffusion Hyperparameters and Schedule
#############################################
T_train = 800  # diffusion steps for training
beta_start = 1e-4
beta_end = 0.02
beta = torch.linspace(beta_start, beta_end, T_train).to(device)  # noise variance schedule
alpha = 1.0 - beta
alpha_hat = torch.cumprod(alpha, dim=0)    # cumulative product for closed-form diffusion

# Loss weightings as in the paper:
w1 = 0.2  # probability-based loss weight (L_prior)
w2 = 0.6  # triplet loss weight

# %%
#############################################
# Step 5: Define the Combined Diffusion Model
# (Incorporates embedding layers for categorical features + MLP for noise prediction)
#############################################
class CombinedNoisePredictor(nn.Module):
    """
    This model exactly follows the paper’s architecture:
    - Numeric (normalized continuous) features are combined with
      embeddings from categorical features.
    - We append a normalized timestep and pass the combined vector
      through an MLP (with LeakyReLU activations) to predict the noise.
      
    This allows us to operate in a continuous space while handling
    categorical variables using learned dense embeddings.
    """
    def __init__(self, num_input_dim, cat_vocab_sizes, cat_embed_dim=2, hidden_dim=256):
        """
        num_input_dim: Dimension of numeric features (e.g., 11)
        cat_vocab_sizes: Dictionary with key = categorical feature name,
                         value = vocabulary size (obtained via the saved cat_vocab)
        cat_embed_dim: The embedding dimension for each categorical feature.
        hidden_dim: Hidden dimension for the MLP.
        """
        super(CombinedNoisePredictor, self).__init__()
        
        # Create an embedding layer for each categorical feature.
        self.embeddings = nn.ModuleDict()
        for col, vocab in cat_vocab_sizes.items():
            # Each embedding layer maps integer codes (0 to vocab_size-1) to a vector
            self.embeddings[col] = nn.Embedding(vocab, cat_embed_dim)
        
        # Total dimension from categorical embeddings:
        cat_total_dim = len(cat_vocab_sizes) * cat_embed_dim
        
        # Combined input = numeric features + categorical embeddings.
        combined_input_dim = num_input_dim + cat_total_dim
        
        # We add +1 to the input dimension to include the normalized timestep.
        self.fc1 = nn.Linear(combined_input_dim + 1, hidden_dim)
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc3 = nn.Linear(hidden_dim, combined_input_dim)
        self.activation = nn.LeakyReLU()
        
    def forward(self, x_num, x_cat, t):
        # Process each categorical feature through its embedding.
        embeds = []
        # The order of features in x_cat must match the order of keys in self.embeddings.
        for i, col in enumerate(self.embeddings):
            emb = self.embeddings[col](x_cat[:, i])
            embeds.append(emb)
        # Concatenate all categorical embeddings into one continuous vector.
        x_cat_emb = torch.cat(embeds, dim=1)
        # Concatenate numeric features and categorical embeddings.
        x = torch.cat([x_num, x_cat_emb], dim=1)
        # Append normalized timestep (t / T_train)
        t_norm = t.unsqueeze(1).float() / T_train
        x_input = torch.cat([x, t_norm], dim=1)
        h = self.activation(self.fc1(x_input))
        h = self.activation(self.fc2(h))
        out = self.fc3(h)
        return out

# Determine vocabulary sizes using the loaded cat_vocab.
# cat_vocab already has integer counts, we just assign them directly
cat_vocab_sizes = {}
for col in cat_features:
    cat_vocab_sizes[col] = cat_vocab[col]
print("Categorical vocabulary sizes:", cat_vocab_sizes)

# Create the model.
num_input_dim = len(num_features)  # E.g., 11
model = CombinedNoisePredictor(num_input_dim=num_input_dim,
                               cat_vocab_sizes=cat_vocab_sizes,
                               cat_embed_dim=2,   # Adjust if needed
                               hidden_dim=256).to(device)
# Out:
# Categorical vocabulary sizes: {'merchant': 693, 'category': 14, 'gender': 2, 'street': 999, 'city': 906, 'state': 51, 'zip': 985, 'job': 497}

# %%
#############################################
# Step 6: Define Loss Functions & Diffusion Process
#############################################
# Compute the adaptive non-fraud prior using the non-fraud numeric data.
X_nonfraud_tensor = torch.tensor(X_nonfraud_num, dtype=torch.float32).to(device)
mu_nf = X_nonfraud_tensor.mean(dim=0, keepdim=True)  # Mean for each numeric feature (shape: [1, num_input_dim])
sigma_nf = X_nonfraud_tensor.std(dim=0, keepdim=True) + 1e-5 # Std (add epsilon to avoid zero division)

def forward_diffusion(x0, t):
    """
    Compute the forward diffusion process using the closed-form solution.
    This is applied ONLY on the numeric portion.
    x0: original numeric features (normalized), shape: (batch, num_input_dim)
    t: timestep tensor, shape: (batch,)
    Returns: x_t (noised sample) and the added noise.
    """
    sqrt_alpha_hat_t = torch.sqrt(alpha_hat[t]).unsqueeze(1)
    sqrt_one_minus_alpha_hat_t = torch.sqrt(1 - alpha_hat[t]).unsqueeze(1)
    noise = torch.randn_like(x0).to(device)
    x_t = sqrt_alpha_hat_t * x0 + sqrt_one_minus_alpha_hat_t * noise
    return x_t, noise

def compute_Lnorm(pred_noise, true_noise):
    """Mean squared error loss between predicted and true noise (numeric only)."""
    return F.mse_loss(pred_noise, true_noise)

def compute_Lprior(pred_noise):
    """
    Compute the probability-based loss (L_prior) using the adaptive non-fraud prior.
    pred_noise: predicted noise (numeric portion), shape: (batch, num_input_dim)
    """
    z = (pred_noise - mu_nf) / sigma_nf
    z_abs = torch.abs(z)
    normal = torch.distributions.Normal(0, 1)
    prob = 1 - normal.cdf(z_abs)  # Tail probability
    L_prior = 1 - 2 * prob
    return L_prior.mean()

def triplet_loss(anchor, positive, negative, margin=1.0):
    """
    Ensure that the denoised sample (anchor) is closer to the real fraud sample (positive)
    than to a non-fraud sample (negative) by at least the margin.
    """
    pos_distance = F.pairwise_distance(anchor, positive, p=2)
    neg_distance = F.pairwise_distance(anchor, negative, p=2)
    loss = F.relu(pos_distance - neg_distance + margin)
    return loss.mean()

# %%
#############################################
# Step 7: Training the Diffusion Model on Fraud Samples
#############################################
loader = DataLoader(fraud_dataset, batch_size=40, shuffle=True)
num_epochs = 250
optimizer = optim.Adam(model.parameters(), lr=0.001)

print("Starting training…")
for epoch in range(num_epochs):
    epoch_loss = 0.0
    for batch in loader:
        x0_num, x0_cat = batch
        # Move batch tensors to device
        x0_num = x0_num.to(device)
        x0_cat = x0_cat.to(device)
        batch_size_curr = x0_num.shape[0]
        t = torch.randint(0, T_train, (batch_size_curr,), device=device)
        
        # Apply forward diffusion on numeric features
        x_t_num, true_noise = forward_diffusion(x0_num, t)
        # Categorical portion remains unchanged
        
        # Pass combined (x_t_num, x0_cat) and timestep t to model
        pred_noise_combined = model(x_t_num, x0_cat, t)
        # Extract numeric noise predictions (first num_input_dim values)
        pred_noise_num = pred_noise_combined[:, :num_input_dim]
        
        L_norm = compute_Lnorm(pred_noise_num, true_noise)
        L_prior = compute_Lprior(pred_noise_num)
        
        # Estimate denoised numeric x0 using one reverse step
        sqrt_alpha_hat_t = torch.sqrt(alpha_hat[t]).unsqueeze(1)
        sqrt_one_minus_alpha_hat_t = torch.sqrt(1 - alpha_hat[t]).unsqueeze(1)
        x0_est_num = (x_t_num - sqrt_one_minus_alpha_hat_t * pred_noise_num) / sqrt_alpha_hat_t
        
        # For triplet loss, sample negatives from non-fraud numeric data
        neg_indices = torch.randint(0, X_nonfraud_tensor.shape[0], (batch_size_curr,), device=device)
        negative_sample = X_nonfraud_tensor[neg_indices]
        L_triplet = triplet_loss(x0_est_num, x0_num, negative_sample)
        
        total_loss = L_norm + w1 * L_prior + w2 * L_triplet
        optimizer.zero_grad()
        total_loss.backward()
        optimizer.step()
        epoch_loss += total_loss.item()
    
    avg_loss = epoch_loss / len(loader)
    if (epoch + 1) % 10 == 0 or epoch == 0:
        print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {avg_loss:.4f}")

print("Training complete. Saving model as 'fraud_diffuse_model_v4_MoreEs.pth'...")
torch.save(model.state_dict(), "fraud_diffuse_model_v4_MoreEs.pth")
print("Model saved.")
# Out:
# Starting training…
# Epoch [1/250], Loss: 0.7910
# Epoch [10/250], Loss: 0.5024
# Epoch [20/250], Loss: 0.4218
# Epoch [30/250], Loss: 0.3818
# Epoch [40/250], Loss: 0.3671
# Epoch [50/250], Loss: 0.3358
# Epoch [60/250], Loss: 0.3255
# Epoch [70/250], Loss: 0.3177
# Epoch [80/250], Loss: 0.2996
# Epoch [90/250], Loss: 0.2910
# Epoch [100/250], Loss: 0.2799
# Epoch [110/250], Loss: 0.2647
# Epoch [120/250], Loss: 0.2576
# Epoch [130/250], Loss: 0.2490
# Epoch [140/250], Loss: 0.2424
# Epoch [150/250], Loss: 0.2402
# Epoch [160/250], Loss: 0.2396
# Epoch [170/250], Loss: 0.2328
# Epoch [180/250], Loss: 0.2324
# Epoch [190/250], Loss: 0.2296
# Epoch [200/250], Loss: 0.2202
# Epoch [210/250], Loss: 0.2197
# Epoch [220/250], Loss: 0.2197
# Epoch [230/250], Loss: 0.2171
# Epoch [240/250], Loss: 0.2146
# Epoch [250/250], Loss: 0.2168
# Training complete. Saving model as 'fraud_diffuse_model_v4_MoreEs.pth'...
# Model saved.

# %%
#############################################
# Step 8: Reload the Model for Synthesis
#############################################
model = CombinedNoisePredictor(num_input_dim=num_input_dim,
                               cat_vocab_sizes=cat_vocab_sizes,
                               cat_embed_dim=2,
                               hidden_dim=256).to(device)
model.load_state_dict(torch.load("fraud_diffuse_model_v4_MoreEs.pth", map_location=device))
model.eval()
print("Model reloaded and set to evaluation mode.")
# Out:
# Model reloaded and set to evaluation mode.

# %%
#############################################
# Step 9: Generate Synthetic Fraud Samples via Reverse Diffusion
#############################################
def generate_synthetic_fraud(model, num_samples, T_gen=T_train):
    """
    Generate synthetic fraud samples:
      - Categorical features are sampled (here uniformly) from the vocabulary.
      - Numeric features are initialized using fraud numeric statistics and then
        synthesized via reverse diffusion.
    Returns:
      (synthetic_numeric, synthetic_categorical)
    """
    model.eval()
    with torch.no_grad():
        # Sample categorical features uniformly
        cat_sample = {}
        for col in cat_vocab_sizes:
            vocab_size = cat_vocab_sizes[col]
            cat_sample[col] = torch.randint(0, vocab_size, (num_samples,), device=device, dtype=torch.long)
        # Order must match cat_features
        x_cat = torch.stack([cat_sample[col] for col in cat_features], dim=1)
        
        # Initialize numeric part using fraud numeric statistics
        X_fraud_tensor = torch.tensor(X_train_num, dtype=torch.float32).to(device)
        noise = torch.randn(num_samples, num_input_dim).to(device)
        x_t_num = X_fraud_tensor.mean(dim=0, keepdim=True).repeat(num_samples, 1) + \
                  X_fraud_tensor.std(dim=0, keepdim=True).repeat(num_samples, 1) * noise
        
        # Reverse diffusion process
        for t_step in reversed(range(1, T_gen)):
            t = torch.full((num_samples,), t_step, device=device, dtype=torch.long)
            combined_pred = model(x_t_num, x_cat, t)
            pred_noise_num = combined_pred[:, :num_input_dim]
            beta_t = beta[t].unsqueeze(1)
            sqrt_alpha_t = torch.sqrt(alpha[t]).unsqueeze(1)
            sqrt_one_minus_alpha_hat_t = torch.sqrt(1 - alpha_hat[t]).unsqueeze(1)
            z = torch.randn_like(x_t_num) if t_step > 1 else torch.zeros_like(x_t_num)
            x_t_num = (x_t_num - (beta_t / sqrt_one_minus_alpha_hat_t) * pred_noise_num) / sqrt_alpha_t \
                      + torch.sqrt(beta_t) * z
        return x_t_num, x_cat

num_synthetic = 200
synthetic_num_norm, synthetic_cat = generate_synthetic_fraud(model, num_synthetic)
print("Synthetic numeric samples shape (normalized):", synthetic_num_norm.shape)
print("Synthetic categorical samples shape:", synthetic_cat.shape)
# Out:
# Synthetic numeric samples shape (normalized): torch.Size([200, 11])
# Synthetic categorical samples shape: torch.Size([200, 8])

# %%
#############################################
# Step 10: Inverse Transform the Numeric Features
#############################################
# Convert normalized numeric samples back to original scale.
synthetic_num_norm_np = synthetic_num_norm.cpu().numpy()
synthetic_num_original = scaler.inverse_transform(synthetic_num_norm_np)

# %%
#############################################
# Step 11: Combine Numeric and Categorical Parts and Evaluate
#############################################
synthetic_numeric_df = pd.DataFrame(synthetic_num_original, columns=num_features)
synthetic_cat_df = pd.DataFrame(synthetic_cat.cpu().numpy(), columns=cat_features)
synthetic_full_df = pd.concat([synthetic_numeric_df, synthetic_cat_df], axis=1)

# For evaluation, compare statistics of numeric features
X_fraud_tensor = torch.tensor(X_train_num, dtype=torch.float32)
real_num_original = scaler.inverse_transform(X_fraud_tensor.cpu().numpy())
real_numeric_df = pd.DataFrame(real_num_original, columns=num_features)

print("Real Fraud Numeric Statistics (Original Scale):")
print(real_numeric_df.describe())
print("\nSynthetic Fraud Numeric Statistics (After Inverse Transform):")
print(synthetic_numeric_df.describe())
# Out:
# Real Fraud Numeric Statistics (Original Scale):
#                amt          lat         long     city_pop    merch_lat  \
# count  6273.000000  6273.000000  6273.000000  6273.000000  6273.000000
# mean      5.553833    38.720264   -90.184822     8.427249    38.711246
# std       1.627878     5.105657    14.214255     2.443052     5.140968
# min       0.722706    20.027100  -165.672302     3.178054    19.161783
# 25%       5.479722    34.990601   -96.790901     6.679599    35.018204
# 50%       5.958528    39.455799   -87.366699     7.940228    39.451233
# 75%       6.802939    42.176701   -80.057297     9.893640    42.062038
# max       7.227692    66.693298   -67.950302    14.882529    67.188110
#
#         merch_long          age    trans_hour    trans_day  trans_month  \
# count  6273.000000  6273.000000  6.273000e+03  6273.000000  6273.000000
# mean    -90.185539    53.622669  1.396126e+01    15.704448     6.399490
# std      14.234361    18.725986  9.707241e+00     8.773403     3.471665
# min    -166.550781    20.000002  3.545246e-08     1.000001     1.000000
# 25%     -96.842262    38.000000  2.000000e+00     8.000000     3.000000
# 50%     -87.415649    52.000000  2.200000e+01    15.000000     6.000000
# 75%     -79.961166    66.000000  2.300000e+01    23.000000     9.000000
# max     -66.960747   100.000000  2.300000e+01    31.000000    12.000000
#
#        trans_dayofweek
# count     6.273000e+03
# mean      3.124024e+00
# std       2.061738e+00
# min       6.516117e-08
# 25%       9.999999e-01
# 50%       3.000000e+00
# 75%       5.000000e+00
# max       6.000000e+00
#
# Synthetic Fraud Numeric Statistics (After Inverse Transform):
#               amt         lat        long    city_pop   merch_lat  merch_long  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean     4.375556   39.002552  -90.117523    8.422951   38.897266  -89.847961
# std      1.785348    4.720563   16.022371    2.246936    4.713065   15.863081
# min      1.750121   22.440908 -141.840591    2.189749   23.286991 -140.629608
# 25%      2.713388   35.887594  -97.109507    7.053707   35.740414  -96.981842
# 50%      3.642488   39.842758  -85.847607    8.260839   39.526649  -85.213085
# 75%      6.241762   42.616173  -77.569248    9.716774   42.516559  -77.334341
# max      7.074422   48.241249  -68.495842   15.859729   48.307232  -68.857101
#
#               age  trans_hour   trans_day  trans_month  trans_dayofweek
# count  200.000000  200.000000  200.000000   200.000000       200.000000
# mean    54.336720   14.398133   14.961399     6.339927         3.448554
# std     18.862867    9.184044    8.145242     3.319783         1.985920
# min      6.889766   -2.188937   -3.207177    -3.618490        -1.736454
# 25%     40.394578    3.618448    8.531272     4.171948         1.917005
# 50%     54.323784   20.013867   14.592115     6.480047         3.484715
# 75%     67.637762   21.793130   21.536390     8.513684         5.142784
# max    101.840446   26.497627   32.305405    13.828777         7.814929

# %%
# Plot distributions for selected features
for col in ['amt', 'city_pop', 'age', 'trans_hour', 'trans_day', 'trans_month', 'trans_dayofweek']:
    plt.figure(figsize=(10, 4))
    sns.histplot(real_numeric_df[col], color='blue', label='Real Fraud', kde=True, bins=30, stat="density")
    sns.histplot(synthetic_numeric_df[col], color='red', label='Synthetic Fraud', kde=True, bins=30, stat="density")
    plt.legend()
    plt.title(f"Distribution of {col}: Real vs Synthetic Fraud")
    plt.xlabel(col)
    plt.ylabel("Density")
    plt.show()
